# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# load the dataset
df = pd.read_csv('/content/drive/MyDrive/DMKD/Project/03. Airline Passenger Satisfaction.csv')

#Check number of rows and columns in the dataset
print("The dataset has %d rows and %d columns." % df.shape)
# Out:
# The dataset has 129880 rows and 25 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         129880 non-null  int64
#  1   id                                 129880 non-null  int64
#  2   Gender                             129880 non-null  object
#  3   Customer Type                      129880 non-null  object
#  4   Age                                129880 non-null  int64
#  5   Type of Travel                     129880 non-null  object
#  6   Class                              129880 non-null  object
#  7   Flight Distance                    129880 non-null  int64
#  8   Inflight wifi service              129880 non-null  int64
#  9   Departure/Arrival time convenient  129880 non-null  int64
#  10  Ease of Online booking             129880 non-null  int64
#  11  Gate location                      129880 non-null  int64
#  12  Food and drink                     129880 non-null  int64
#  13  Online boarding                    129880 non-null  int64
#  14  Seat comfort                       129880 non-null  int64
#  15  Inflight entertainment             129880 non-null  int64
#  16  On-board service                   129880 non-null  int64
#  17  Leg room service                   129880 non-null  int64
#  18  Baggage handling                   129880 non-null  int64
#  19  Checkin service                    129880 non-null  int64
#  20  Inflight service                   129880 non-null  int64
#  21  Cleanliness                        129880 non-null  int64
#  22  Departure Delay in Minutes         129880 non-null  int64
#  23  Arrival Delay in Minutes           129487 non-null  float64
#  24  satisfaction                       129880 non-null  object
# dtypes: float64(1), int64(19), object(5)
# memory usage: 24.8+ MB

# %%
df.head(20)
# Out:
#     Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 0            0   70172  ...                     18.0  neutral or dissatisfied
# 1            1    5047  ...                      6.0  neutral or dissatisfied
# 2            2  110028  ...                      0.0                satisfied
# 3            3   24026  ...                      9.0  neutral or dissatisfied
# 4            4  119299  ...                      0.0                satisfied
# 5            5  111157  ...                      0.0  neutral or dissatisfied
# 6            6   82113  ...                     23.0  neutral or dissatisfied
# 7            7   96462  ...                      0.0                satisfied
# 8            8   79485  ...                      0.0  neutral or dissatisfied
# 9            9   65725  ...                      0.0  neutral or dissatisfied
# 10          10   34991  ...                      0.0  neutral or dissatisfied
# 11          11   51412  ...                      0.0  neutral or dissatisfied
# 12          12   98628  ...                      8.0  neutral or dissatisfied
# 13          13   83502  ...                      0.0                satisfied
# 14          14   95789  ...                     35.0  neutral or dissatisfied
# 15          15  100580  ...                      0.0  neutral or dissatisfied
# 16          16   71142  ...                     51.0                satisfied
# 17          17  127461  ...                     10.0                satisfied
# 18          18   70354  ...                      5.0                satisfied
# 19          19   66246  ...                     18.0  neutral or dissatisfied
#
# [20 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# dtype: int64

# %%
missing_values = df[pd.isnull(df).any(axis=1)]

# %%
missing_values
# Out:
#         Unnamed: 0      id  ... Arrival Delay in Minutes             satisfaction
# 213            213   49608  ...                      NaN                satisfied
# 1124          1124   73442  ...                      NaN  neutral or dissatisfied
# 1529          1529   71178  ...                      NaN  neutral or dissatisfied
# 2004          2004   72940  ...                      NaN  neutral or dissatisfied
# 2108          2108  116374  ...                      NaN  neutral or dissatisfied
# ...            ...     ...  ...                      ...                      ...
# 127976      127976   21780  ...                      NaN                satisfied
# 128037      128037   64934  ...                      NaN  neutral or dissatisfied
# 128205      128205  125688  ...                      NaN                satisfied
# 129032      129032   64706  ...                      NaN                satisfied
# 129372      129372   85927  ...                      NaN  neutral or dissatisfied
#
# [393 rows x 25 columns]

# %%
df2 = df.drop(columns=['Unnamed: 0' , 'id'] ,inplace=False )

# %%
df2.head(10)
# Out:
#    Gender      Customer Type  ...  Arrival Delay in Minutes             satisfaction
# 0    Male     Loyal Customer  ...                      18.0  neutral or dissatisfied
# 1    Male  disloyal Customer  ...                       6.0  neutral or dissatisfied
# 2  Female     Loyal Customer  ...                       0.0                satisfied
# 3  Female     Loyal Customer  ...                       9.0  neutral or dissatisfied
# 4    Male     Loyal Customer  ...                       0.0                satisfied
# 5  Female     Loyal Customer  ...                       0.0  neutral or dissatisfied
# 6    Male     Loyal Customer  ...                      23.0  neutral or dissatisfied
# 7  Female     Loyal Customer  ...                       0.0                satisfied
# 8  Female     Loyal Customer  ...                       0.0  neutral or dissatisfied
# 9    Male  disloyal Customer  ...                       0.0  neutral or dissatisfied
#
# [10 rows x 23 columns]

# %%
df2.isnull().sum()
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# dtype: int64

# %%
df2["Gender"]=df2["Gender"].apply(lambda x: 0 if x=="Male" else 1)

# %%
df2.columns = df2.columns.str.replace(' ','_')

# %%
df2.head(10)
# Out:
#    Gender      Customer_Type  ...  Arrival_Delay_in_Minutes             satisfaction
# 0       0     Loyal Customer  ...                      18.0  neutral or dissatisfied
# 1       0  disloyal Customer  ...                       6.0  neutral or dissatisfied
# 2       1     Loyal Customer  ...                       0.0                satisfied
# 3       1     Loyal Customer  ...                       9.0  neutral or dissatisfied
# 4       0     Loyal Customer  ...                       0.0                satisfied
# 5       1     Loyal Customer  ...                       0.0  neutral or dissatisfied
# 6       0     Loyal Customer  ...                      23.0  neutral or dissatisfied
# 7       1     Loyal Customer  ...                       0.0                satisfied
# 8       1     Loyal Customer  ...                       0.0  neutral or dissatisfied
# 9       0  disloyal Customer  ...                       0.0  neutral or dissatisfied
#
# [10 rows x 23 columns]

# %%
df2["Customer_Type"]= df2["Customer_Type"].apply(lambda x: 0 if x=="Loyal Customer" else 1)

# %%
df2["Type_of_Travel"]= df2["Type_of_Travel"].apply(lambda x: 0 if x=="Personal Travel" else 1)

# %%
df2["Class"]= df2["Class"].apply(lambda x: 0 if x=="Eco Plus" else (1 if x=="Business" else 2 ))

# %%
df2["satisfaction"]= df2["satisfaction"].apply(lambda x: 0 if x=="neutral or dissatisfied" else 1)

# %%
df2.head(30)
# Out:
#     Gender  Customer_Type  ...  Arrival_Delay_in_Minutes  satisfaction
# 0        0              0  ...                      18.0             0
# 1        0              1  ...                       6.0             0
# 2        1              0  ...                       0.0             1
# 3        1              0  ...                       9.0             0
# 4        0              0  ...                       0.0             1
# 5        1              0  ...                       0.0             0
# 6        0              0  ...                      23.0             0
# 7        1              0  ...                       0.0             1
# 8        1              0  ...                       0.0             0
# 9        0              1  ...                       0.0             0
# 10       1              1  ...                       0.0             0
# 11       1              0  ...                       0.0             0
# 12       0              0  ...                       8.0             0
# 13       0              0  ...                       0.0             1
# 14       1              0  ...                      35.0             0
# 15       0              1  ...                       0.0             0
# 16       1              0  ...                      51.0             1
# 17       0              0  ...                      10.0             1
# 18       1              0  ...                       5.0             1
# 19       0              0  ...                      18.0             0
# 20       0              0  ...                       4.0             0
# 21       1              0  ...                       0.0             0
# 22       1              0  ...                      29.0             0
# 23       1              0  ...                       0.0             0
# 24       1              1  ...                      44.0             1
# 25       0              0  ...                      28.0             0
# 26       1              0  ...                       0.0             1
# 27       1              0  ...                       8.0             1
# 28       1              0  ...                      12.0             0
# 29       0              0  ...                       0.0             0
#
# [30 rows x 23 columns]

# %% [markdown]
# # ------------Replapcing Nulls with Mean:-----------

# %%
#df2=df2.fillna(df2.mean())
df2['Arrival_Delay_in_Minutes'] = df2['Arrival_Delay_in_Minutes'].fillna(0, inplace=False)

# %%
df2.isnull().sum()
# Out:
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %%
df2.iloc[109]
# Out:
# Gender                                  1.0
# Customer_Type                           0.0
# Age                                    26.0
# Type_of_Travel                          0.0
# Class                                   2.0
# Flight_Distance                      1144.0
# Inflight_wifi_service                   3.0
# Departure/Arrival_time_convenient       5.0
# Ease_of_Online_booking                  2.0
# Gate_location                           2.0
# Food_and_drink                          4.0
# Online_boarding                         2.0
# Seat_comfort                            4.0
# Inflight_entertainment                  4.0
# On-board_service                        5.0
# Leg_room_service                        4.0
# Baggage_handling                        5.0
# Checkin_service                         3.0
# Inflight_service                        5.0
# Cleanliness                             4.0
# Departure_Delay_in_Minutes              0.0
# Arrival_Delay_in_Minutes                0.0
# satisfaction                            0.0
# Name: 109, dtype: float64

# %%
missing_values = df2[pd.isnull(df2).any(axis=1)]

# %%
missing_values
# Out:
# Empty DataFrame
# Columns: [Gender, Customer_Type, Age, Type_of_Travel, Class, Flight_Distance, Inflight_wifi_service, Departure/Arrival_time_convenient, Ease_of_Online_booking, Gate_location, Food_and_drink, Online_boarding, Seat_comfort, Inflight_entertainment, On-board_service, Leg_room_service, Baggage_handling, Checkin_service, Inflight_service, Cleanliness, Departure_Delay_in_Minutes, Arrival_Delay_in_Minutes, satisfaction]
# Index: []

# %%
df2.describe()
# Out:
#               Gender  Customer_Type  ...  Arrival_Delay_in_Minutes   satisfaction
# count  129880.000000  129880.000000  ...             129880.000000  129880.000000
# mean        0.507384       0.183092  ...                 15.045465       0.434463
# std         0.499947       0.386743  ...                 38.416353       0.495688
# min         0.000000       0.000000  ...                  0.000000       0.000000
# 25%         0.000000       0.000000  ...                  0.000000       0.000000
# 50%         1.000000       0.000000  ...                  0.000000       0.000000
# 75%         1.000000       0.000000  ...                 13.000000       1.000000
# max         1.000000       1.000000  ...               1584.000000       1.000000
#
# [8 rows x 23 columns]

# %%
#df2['Age'] = (df2['Age']-df2['Age'].min()) / (df2['Age'].max()-df2['Age'].min())

# %%
#df2['Flight_Distance'] = (df2['Flight_Distance']-df2['Flight_Distance'].min()) / (df2['Flight_Distance'].max()-df2['Flight_Distance'].min())

# %%
#df2['Inflight_wifi_service'] = (df2['Inflight_wifi_service']-df2['Inflight_wifi_service'].min()) / (df2['Inflight_wifi_service'].max()-df2['Inflight_wifi_service'].min())

# %%
#df2['Departure/Arrival_time_convenient'] = (df2['Departure/Arrival_time_convenient']-df2['Departure/Arrival_time_convenient'].min()) / (df2['Departure/Arrival_time_convenient'].max()-df2['Departure/Arrival_time_convenient'].min())

# %%
#df2['Ease_of_Online_booking'] = (df2['Ease_of_Online_booking']-df2['Ease_of_Online_booking'].min()) / (df2['Ease_of_Online_booking'].max()-df2['Ease_of_Online_booking'].min())

# %%
#df2['Gate_location'] = (df2['Gate_location']-df2['Gate_location'].min()) / (df2['Gate_location'].max()-df2['Gate_location'].min())

# %%
#df2['Food_and_drink'] = (df2['Food_and_drink']-df2['Food_and_drink'].min()) / (df2['Food_and_drink'].max()-df2['Food_and_drink'].min())

# %%
#df2['Online_boarding'] = (df2['Online_boarding']-df2['Online_boarding'].min()) / (df2['Online_boarding'].max()-df2['Online_boarding'].min())

# %%
#df2['Seat_comfort'] = (df2['Seat_comfort']-df2['Seat_comfort'].min()) / (df2['Seat_comfort'].max()-df2['Seat_comfort'].min())

# %%
#df2['Inflight_entertainment'] = (df2['Inflight_entertainment']-df2['Inflight_entertainment'].min()) / (df2['Inflight_entertainment'].max()-df2['Inflight_entertainment'].min())

# %%
#df2['On-board_service'] = (df2['On-board_service']-df2['On-board_service'].min()) / (df2['On-board_service'].max()-df2['On-board_service'].min())

# %%
#df2['Leg_room_service'] = (df2['Leg_room_service']-df2['Leg_room_service'].min()) / (df2['Leg_room_service'].max()-df2['Leg_room_service'].min())

# %%
#df2['Baggage_handling'] = (df2['Baggage_handling']-df2['Baggage_handling'].min()) / (df2['Baggage_handling'].max()-df2['Baggage_handling'].min())

# %%
#df2['Checkin_service'] = (df2['Checkin_service']-df2['Checkin_service'].min()) / (df2['Checkin_service'].max()-df2['Checkin_service'].min())

# %%
#df2['Inflight_service'] = (df2['Inflight_service']-df2['Inflight_service'].min()) / (df2['Inflight_service'].max()-df2['Inflight_service'].min())

# %%
#df2['Cleanliness'] = (df2['Cleanliness']-df2['Cleanliness'].min()) / (df2['Cleanliness'].max()-df2['Cleanliness'].min())

# %%
#df2['Departure_Delay_in_Minutes'] = (df2['Departure_Delay_in_Minutes']-df2['Departure_Delay_in_Minutes'].min()) / (df2['Departure_Delay_in_Minutes'].max()-df2['Departure_Delay_in_Minutes'].min())

# %%
#df2['Arrival_Delay_in_Minutes'] = (df2['Arrival_Delay_in_Minutes']-df2['Arrival_Delay_in_Minutes'].min()) / (df2['Arrival_Delay_in_Minutes'].max()-df2['Arrival_Delay_in_Minutes'].min())

# %%
df2.head(10)
# Out:
#    Gender  Customer_Type  ...  Arrival_Delay_in_Minutes  satisfaction
# 0       0              0  ...                      18.0             0
# 1       0              1  ...                       6.0             0
# 2       1              0  ...                       0.0             1
# 3       1              0  ...                       9.0             0
# 4       0              0  ...                       0.0             1
# 5       1              0  ...                       0.0             0
# 6       0              0  ...                      23.0             0
# 7       1              0  ...                       0.0             1
# 8       1              0  ...                       0.0             0
# 9       0              1  ...                       0.0             0
#
# [10 rows x 23 columns]

# %%
# Import the packages

import pandas as pd
import numpy as np
import itertools


import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set(style='whitegrid', palette='muted', font_scale=1.5)
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8
import os

# Any results you write to the current directory are saved as output.

# %%
df2 = df2.head(500)

# %% [markdown]
# # Exploring the dataset

# %%
sns.countplot(x='satisfaction',data=df2)
plt.show()

# %%
df2.describe()
# Out:
#            Gender  Customer_Type  ...  Arrival_Delay_in_Minutes  satisfaction
# count  500.000000     500.000000  ...                500.000000    500.000000
# mean     0.522000       0.156000  ...                 13.662000      0.444000
# std      0.500016       0.363219  ...                 29.450474      0.497352
# min      0.000000       0.000000  ...                  0.000000      0.000000
# 25%      0.000000       0.000000  ...                  0.000000      0.000000
# 50%      1.000000       0.000000  ...                  0.000000      0.000000
# 75%      1.000000       0.000000  ...                 13.000000      1.000000
# max      1.000000       1.000000  ...                191.000000      1.000000
#
# [8 rows x 23 columns]

# %%
grouped = df2.groupby('satisfaction').agg({'Gender':['mean', 'std', min, max], 
                                       'Customer_Type':['mean', 'std', min, max],
                                       'Age':['mean', 'std', min, max],
                                       'Type_of_Travel':['mean', 'std', min, max],
                                       'Class':['mean', 'std', min, max],
                                       'Flight_Distance':['mean', 'std', min, max],
                                       'Inflight_wifi_service':['mean', 'std', min, max],
                                       'Departure/Arrival_time_convenient':['mean', 'std', min, max],
                                       'Ease_of_Online_booking':['mean', 'std', min, max],
                                       'Gate_location':['mean', 'std', min, max],
                                       'Food_and_drink':['mean', 'std', min, max],
                                       'Online_boarding':['mean', 'std', min, max],
                                       'Seat_comfort':['mean', 'std', min, max],
                                       'Inflight_entertainment':['mean', 'std', min, max],
                                       'On-board_service':['mean', 'std', min, max],
                                       'Leg_room_service':['mean', 'std', min, max],
                                       'Baggage_handling':['mean', 'std', min, max],
                                       'Checkin_service':['mean', 'std', min, max],
                                       'Inflight_service':['mean', 'std', min, max],
                                       'Cleanliness':['mean', 'std', min, max],
                                       'Departure_Delay_in_Minutes':['mean', 'std', min, max],
                                       'Arrival_Delay_in_Minutes':['mean', 'std', min, max]
                                       
                                      })
grouped.columns = ["_".join(x) for x in grouped.columns.ravel()]
grouped # or grouped.T
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#               Gender_mean  ...  Arrival_Delay_in_Minutes_max
# satisfaction               ...
# 0                0.550360  ...                         185.0
# 1                0.486486  ...                         191.0
#
# [2 rows x 88 columns]

# %% [markdown]
# Let us have look at the distribution of the features grouping them by the Outcome column.
# Outcome 0 is Neutral or dissatisfied, 1 is with satisfied.

# %%
plt.subplots_adjust(top=5)
columns=df2.columns[:22]
plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(df2[columns]):
    ax = plt.subplot(gs[i])
    sns.distplot(df2[cn][df2.satisfaction == 1], bins=50)
    sns.distplot(df2[cn][df2.satisfaction == 0], bins=50)
    ax.set_xlabel('')
    plt.legend(df2["satisfaction"])
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.heatmap(df2[df2.columns[:22]].corr(),annot=True,cmap='RdYlGn')
fig=plt.gcf()
plt.show()

# %% [markdown]
# # **Model Building**

# %%
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier 
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Split into train and test stratifying the 'Outcome' column.
# This guarantees the train-test split ratio in the 'Outcome' column both in the training set and the testing set.

# %% [markdown]
# # **Methods for evaluating the performance of a Classifier**

# %% [markdown]
# ## **Holdout Method**

# %% [markdown]
# In the holdout method, the original data with labeled examples is partitioned into
# two disjoint sets, called the training and the test sets, respectively. A classifica-
# tion model is then induced from the training set and its performance is evaluated
# on the test set. The proportion of data reserved for training and for testing is
# typically at the discretion of the analysts (e.g., 50-50 or two- thirds for training
# and one-third for testing). The accuracy of the classifier can be estimated based
# on the accuracy of the induced model on the test set.

# %%
satisfaction=df2['satisfaction']
data=df2[df2.columns[:22]]

train,test=train_test_split(df2,test_size=0.25,random_state=0,stratify=df2['satisfaction'])# stratify the outcome

train_X=train[train.columns[:22]]
test_X=test[test.columns[:22]]
train_Y=train['satisfaction']
test_Y=test['satisfaction']

# %% [markdown]
# ### **Feature Centering and Scaling**
#
# train_X and test_X datasets are centered to zero and normalized by the std dev. This helps in faster gradient descent.

# %%
features = train_X.columns.values

for feature in features:
    mean, std = df2[feature].mean(), df2[feature].std()
    train_X.loc[:, feature] = (train_X[feature] - mean) / std
    test_X.loc[:, feature] = (test_X[feature] - mean) / std

# %% [markdown]
# ### **Compare model accuracies**

# %%
accuracy_scores=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree', 'Random forest', 'Naive Bayes']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),
        KNeighborsClassifier(n_neighbors=3),DecisionTreeClassifier(), 
        RandomForestClassifier(n_estimators=100,random_state=0), GaussianNB()]
for i in models:
    model = i
    model.fit(train_X,train_Y)
    prediction=model.predict(test_X)
    accuracy_scores.append(metrics.accuracy_score(prediction,test_Y))
    
models_dataframe=pd.DataFrame(accuracy_scores,index=classifiers)   
models_dataframe.columns=['Accuracy']
models_dataframe.sort_values(['Accuracy'], ascending=[0])
# Out:
#                      Accuracy
# Random forest           0.888
# Radial Svm              0.880
# Naive Bayes             0.864
# KNN                     0.856
# Decision Tree           0.856
# Linear Svm              0.840
# Logistic Regression     0.832

# %% [markdown]
# We see that Decision Tree	classifier has better accuracy of 0.896%.Let us look at the feature importance in Decision Tree classifier.

# %%
modelRF= DecisionTreeClassifier()
modelRF.fit(train_X,train_Y)
predictionRF=modelRF.predict(test_X)
pd.Series(modelRF.feature_importances_,index=train_X.columns).sort_values(ascending=False)
# Out:
# Online_boarding                      0.401797
# Inflight_wifi_service                0.148283
# Type_of_Travel                       0.097120
# Customer_Type                        0.051962
# Leg_room_service                     0.040571
# Age                                  0.038611
# Class                                0.034961
# Cleanliness                          0.031235
# Flight_Distance                      0.029104
# Departure/Arrival_time_convenient    0.024846
# Inflight_entertainment               0.023614
# Departure_Delay_in_Minutes           0.023355
# Checkin_service                      0.015290
# Baggage_handling                     0.012528
# Inflight_service                     0.011710
# On-board_service                     0.005404
# Ease_of_Online_booking               0.005404
# Seat_comfort                         0.004203
# Gender                               0.000000
# Food_and_drink                       0.000000
# Gate_location                        0.000000
# Arrival_Delay_in_Minutes             0.000000
# dtype: float64

# %% [markdown]
# feature importance in Decision RandomForestClassifier.

# %%
modelRF= RandomForestClassifier(n_estimators=100,random_state=0)
modelRF.fit(train_X,train_Y)
predictionRF=modelRF.predict(test_X)
pd.Series(modelRF.feature_importances_,index=train_X.columns).sort_values(ascending=False)
# Out:
# Online_boarding                      0.185643
# Inflight_wifi_service                0.092335
# Inflight_entertainment               0.078587
# Type_of_Travel                       0.068360
# Flight_Distance                      0.060624
# Age                                  0.059248
# Leg_room_service                     0.050608
# On-board_service                     0.050464
# Class                                0.048186
# Ease_of_Online_booking               0.037336
# Seat_comfort                         0.032970
# Baggage_handling                     0.029481
# Inflight_service                     0.026361
# Customer_Type                        0.025883
# Cleanliness                          0.025669
# Checkin_service                      0.023991
# Gate_location                        0.021779
# Departure/Arrival_time_convenient    0.020981
# Departure_Delay_in_Minutes           0.020143
# Arrival_Delay_in_Minutes             0.018556
# Food_and_drink                       0.015804
# Gender                               0.006990
# dtype: float64

# %% [markdown]
# ## **k-fold Cross validation**

# %% [markdown]
# An alternative to random subsampling is cross-validation. In this approach, each
# record is used the same number of times for training and exactly once for test-
# ing. To illustrate this method, suppose we partition the data into two equal-sized
# subsets. First, we choose one of the subsets for training and the other for testing.
# We then swap the roles of the subsets so that the previous training set becomes
# the test set and vice versa. This approach is called a two- fold cross-validation.
# The total error is obtained by summing up the errors for both runs. In this exam-
# ple, each record is used exactly once for training and once for testing.

# %% [markdown]
# Most of the time, the dataset has imbalance in classes, say one or more class(es) has higher instances than the other classes. In that case, we should train the model in each and every instances of the dataset. After that we take average of all the noted accuracies over the dataset.
#
# For a K-fold cross validation, we first divide the dataset into K subsets.
# Then we train on K-1 parts and test on the remainig 1 part.
# We continue to do that by taking each part as testing and training on the remaining K-1. Accuracies and errors are then averaged to get an average accuracy of the algorithm.
#
# For certain subset the algorithm will underfit while for a certain other it will overfit. With K-fold cross validation we achieve a generalized model.
#
# Below we approach the K-fold cross validation for this dataset.

# %%
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.preprocessing import StandardScaler #Standardisation

# %%
kfold = KFold(n_splits=10, random_state=42, shuffle=True) # k=10 splits the data into 10 equal parts

# %%
df2.describe()
# Out:
#            Gender  Customer_Type  ...  Arrival_Delay_in_Minutes  satisfaction
# count  500.000000     500.000000  ...                500.000000    500.000000
# mean     0.522000       0.156000  ...                 13.662000      0.444000
# std      0.500016       0.363219  ...                 29.450474      0.497352
# min      0.000000       0.000000  ...                  0.000000      0.000000
# 25%      0.000000       0.000000  ...                  0.000000      0.000000
# 50%      1.000000       0.000000  ...                  0.000000      0.000000
# 75%      1.000000       0.000000  ...                 13.000000      1.000000
# max      1.000000       1.000000  ...                191.000000      1.000000
#
# [8 rows x 23 columns]

# %%
# Starting with the original dataset and then doing centering and scaling
features=df2[df2.columns[:22]]
features_standard=StandardScaler().fit_transform(features)# Gaussian Standardisation
X=pd.DataFrame(features_standard,columns=['Gender',	'Customer_Type',	'Age',	'Type_of_Travel',	'Class',	'Flight_Distance'	,'Inflight_wifi_service',	'Departure/Arrival_time_convenient',	'Ease_of_Online_booking',	'Gate_location'	,'Food_and_drink',	'Online_boarding',	'Seat_comfort',	'Inflight_entertainment',	'On-board_service',	'Leg_room_service',	'Baggage_handling',	'Checkin_service'	,'Inflight_service',	'Cleanliness',	'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes'])
X['satisfaction']=df2['satisfaction']

# %%
xyz=[]
accuracy=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree', 'Random forest', 'Naive Bayes']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),
        KNeighborsClassifier(n_neighbors=3),DecisionTreeClassifier(), 
        RandomForestClassifier(n_estimators=100,random_state=0), GaussianNB()]

for i in models:
    model = i
    cv_result = cross_val_score(model,X[X.columns[:22]], X['satisfaction'], cv = kfold, scoring = "accuracy")
    cv_result=cv_result
    xyz.append(cv_result.mean())
    accuracy.append(cv_result)

cv_models_dataframe=pd.DataFrame(xyz, index=classifiers)   
cv_models_dataframe.columns=['CV Mean']    
cv_models_dataframe
cv_models_dataframe.sort_values(['CV Mean'], ascending=[0])
# Out:
#                      CV Mean
# Radial Svm             0.912
# Random forest          0.896
# KNN                    0.872
# Logistic Regression    0.860
# Naive Bayes            0.858
# Linear Svm             0.854
# Decision Tree          0.836

# %%
kfold = KFold(n_splits=20, random_state=42, shuffle=True) # k=20 splits the data into 20 equal parts

# %%
# Starting with the original dataset and then doing centering and scaling
features=df2[df2.columns[:22]]
features_standard=StandardScaler().fit_transform(features)# Gaussian Standardisation
X=pd.DataFrame(features_standard,columns=['Gender',	'Customer_Type',	'Age',	'Type_of_Travel',	'Class',	'Flight_Distance'	,'Inflight_wifi_service',	'Departure/Arrival_time_convenient',	'Ease_of_Online_booking',	'Gate_location'	,'Food_and_drink',	'Online_boarding',	'Seat_comfort',	'Inflight_entertainment',	'On-board_service',	'Leg_room_service',	'Baggage_handling',	'Checkin_service'	,'Inflight_service',	'Cleanliness',	'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes'])
X['satisfaction']=df2['satisfaction']

# %%
xyz=[]
accuracy=[]
classifiers=['Linear Svm','Radial Svm','Logistic Regression','KNN','Decision Tree', 'Random forest', 'Naive Bayes']
models=[svm.SVC(kernel='linear'),svm.SVC(kernel='rbf'),LogisticRegression(),
        KNeighborsClassifier(n_neighbors=3),DecisionTreeClassifier(), 
        RandomForestClassifier(n_estimators=100,random_state=0), GaussianNB()]

for i in models:
    model = i
    cv_result = cross_val_score(model,X[X.columns[:22]], X['satisfaction'], cv = kfold, scoring = "accuracy")
    cv_result=cv_result
    xyz.append(cv_result.mean())
    accuracy.append(cv_result)

cv_models_dataframe=pd.DataFrame(xyz, index=classifiers)   
cv_models_dataframe.columns=['CV Mean']    
cv_models_dataframe
cv_models_dataframe.sort_values(['CV Mean'], ascending=[0])
# Out:
#                      CV Mean
# Radial Svm             0.906
# Random forest          0.896
# KNN                    0.876
# Naive Bayes            0.860
# Linear Svm             0.854
# Decision Tree          0.852
# Logistic Regression    0.852

# %% [markdown]
# # **Comparing data mining methods**

# %% [markdown]
# We often need to compare two different learning methods on the same problem
# to see which is the better one to use. It seems simple: estimate the error using
# cross-validation (or any other suitable estimation procedure), perhaps repeated
# several times, and choose the scheme whose estimate is smaller. This is quite
# sufficient in many practical applications: if one method has a lower estimated
# error than another on a particular dataset, the best we can do is to use the former
# method’s model.

# %% [markdown]
# However, it may be that the difference is simply caused by estimation error,
# and in some circumstances it is important to determine whether one scheme is
# really better than another on a particular problem. This is a standard challenge
# for machine learning researchers. If a new learning algorithm is proposed, its
# proponents must show that it improves on the state of the art for the problem at
# hand and demonstrate that the observed improvement is not just a chance effect
# in the estimation process.

# %%
box=pd.DataFrame(accuracy,index=[classifiers])
boxT = box.T

# %%
ax = sns.boxplot(data=boxT, orient="h", palette="Set2", width=.6)
ax.set_yticklabels(classifiers)
ax.set_title('Cross validation accuracies with different classifiers')
ax.set_xlabel('Accuracy')
plt.show()

# %% [markdown]
# The above plots shows that:
# Random forest>Radial Svm.

# %% [markdown]
# # **Ensembling**

# %%
DecisionTree = DecisionTreeClassifier(max_depth=10)
KNN = KNeighborsClassifier(n_neighbors=7)
radial_svm=svm.SVC(kernel='rbf',C=0.1,gamma=10, probability=True)

# %%
from sklearn.ensemble import VotingClassifier #for Voting Classifier

# %% [markdown]
# ## **Ensamble with 3 classifiers combined: radial SVM, Decision tree, KNN**

# %%
ensembleModel=VotingClassifier(estimators=[('DecisionTree',DecisionTree), ('KNN', KNN), ('radial_svm', radial_svm)], 
                                            voting='soft', weights=[1,2,3])

ensembleModel.fit(train_X,train_Y)
predictEnsemble = ensembleModel.predict(test_X)

# %%
print('Accuracy of ensembled model with all the 3 classifiers is:', np.round(ensembleModel.score(test_X,test_Y), 4))
# Out:
# Accuracy of ensembled model with all the 3 classifiers is: 0.904

# %% [markdown]
# # **ROC curve with AUC**

# %% [markdown]
# Lift charts are a valuable tool, widely used in marketing. They are closely re-
# lated to a graphical technique for evaluating data mining schemes known as ROC
# curves, which are used in just the same situation as the preceding one, in which
# the learner is trying to select samples of test instances that have a high propor-
# tion of positives. The acronym stands for receiver operating characteristic, a
# term used in signal detection to characterize the trade-off between hit rate and
# false alarm rate over a noisy channel.
# ROC curves depict the performance of a classifier without regard to class distri-
# bution or error costs.

# %%
from sklearn import metrics
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc, roc_curve, recall_score, 
                             classification_report, f1_score, average_precision_score, precision_recall_fscore_support)

# %% [markdown]
# ### **For the ensembling method**

# %%
from sklearn.metrics import roc_curve, auc
false_positive_rate, true_positive_rate, thresholds = roc_curve(test_Y, predictEnsemble)
roc_auc = auc(false_positive_rate, true_positive_rate)
roc_auc
# Out:
# 0.9012681159420289

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Receiver Operating Characteristic for ensembling method')
plt.plot(false_positive_rate,true_positive_rate, color='red',label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],linestyle='--')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
# Text(0.5, 0, 'False Positive Rate')

# %% [markdown]
# ### **For all methods**

# %%
# Logistic regression
modelLR = LogisticRegression()
modelLR.fit(train_X,train_Y)
y_pred_prob_lr = modelLR.predict_proba(test_X)[:,1]
fpr_lr, tpr_lr, thresholds_lr = roc_curve(test_Y, y_pred_prob_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
precision_lr, recall_lr, th_lr = precision_recall_curve(test_Y, y_pred_prob_lr)

# SVM with rbf
modelSVMrbf=svm.SVC(kernel='rbf', probability=True)
modelSVMrbf.fit(train_X,train_Y)
y_pred_prob_SVMrbf = modelSVMrbf.predict_proba(test_X)[:,1]
fpr_SVMrbf, tpr_SVMrbf, thresholds_SVMrbf = roc_curve(test_Y, y_pred_prob_SVMrbf)
roc_auc_SVMrbf = auc(fpr_SVMrbf, tpr_SVMrbf)
precision_SVMrbf, recall_SVMrbf, th_SVMrbf = precision_recall_curve(test_Y, y_pred_prob_SVMrbf)

# SVM with linear
modelSVMlinear=svm.SVC(kernel='linear', probability=True)
modelSVMlinear.fit(train_X,train_Y)
y_pred_prob_SVMlinear = modelSVMlinear.predict_proba(test_X)[:,1]
fpr_SVMlinear, tpr_SVMlinear, thresholds_SVMlinear = roc_curve(test_Y, y_pred_prob_SVMlinear)
roc_auc_SVMlinear = auc(fpr_SVMlinear, tpr_SVMlinear)
precision_SVMlinear, recall_SVMlinear, th_SVMlinear = precision_recall_curve(test_Y, y_pred_prob_SVMlinear)

# KNN
modelKNN = KNeighborsClassifier(n_neighbors=7)
modelKNN.fit(train_X,train_Y)
y_pred_prob_KNN = modelKNN.predict_proba(test_X)[:,1]
fpr_KNN, tpr_KNN, thresholds_KNN = roc_curve(test_Y, y_pred_prob_KNN)
roc_auc_KNN = auc(fpr_KNN, tpr_KNN)
precision_KNN, recall_KNN, th_KNN = precision_recall_curve(test_Y, y_pred_prob_KNN)


# Decision Tree
modelTree=DecisionTreeClassifier()
modelTree.fit(train_X,train_Y)
y_pred_prob_Tree = modelTree.predict_proba(test_X)[:,1]
fpr_Tree, tpr_Tree, thresholds_Tree = roc_curve(test_Y, y_pred_prob_Tree)
roc_auc_Tree = auc(fpr_Tree, tpr_Tree)
precision_Tree, recall_Tree, th_Tree = precision_recall_curve(test_Y, y_pred_prob_Tree)

# Random forest
modelRF= RandomForestClassifier(n_estimators=100,random_state=0)
modelRF.fit(train_X,train_Y)
y_pred_prob_rf = modelRF.predict_proba(test_X)[:,1]
fpr_rf, tpr_rf, thresholds_rf = roc_curve(test_Y, y_pred_prob_rf)
roc_auc_rf = auc(fpr_rf, tpr_rf)
precision_rf, recall_rf, th_rf = precision_recall_curve(test_Y, y_pred_prob_rf)


# Naive Bayes
modelNB= GaussianNB()
modelNB.fit(train_X,train_Y)
y_pred_prob_nb = modelNB.predict_proba(test_X)[:,1]
fpr_nb, tpr_nb, thresholds_nb = roc_curve(test_Y, y_pred_prob_nb)
roc_auc_nb = auc(fpr_nb, tpr_nb)
precision_nb, recall_nb, th_nb = precision_recall_curve(test_Y, y_pred_prob_nb)

# Ensamble 
y_pred_prob_en = ensembleModel.predict_proba(test_X)[:,1]
fpr_en, tpr_en, thresholds_en = roc_curve(test_Y, y_pred_prob_en)
roc_auc_en = auc(fpr_en, tpr_en)
precision_en, recall_en, th_en = precision_recall_curve(test_Y, y_pred_prob_en)

# %%
# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_lr, tpr_lr, label='Log Reg (area = %0.3f)' % roc_auc_lr)
plt.plot(fpr_SVMrbf, tpr_SVMrbf, label='SVM rbf (area = %0.3f)' % roc_auc_SVMrbf)
plt.plot(fpr_SVMlinear, tpr_SVMlinear, label='SVM linear (area = %0.3f)' % roc_auc_SVMlinear)
plt.plot(fpr_KNN, tpr_KNN, label='KNN (area = %0.3f)' % roc_auc_KNN)
plt.plot(fpr_Tree, tpr_Tree, label='Tree (area = %0.3f)' % roc_auc_Tree)
plt.plot(fpr_rf, tpr_rf, label='RF (area = %0.3f)' % roc_auc_rf)
plt.plot(fpr_nb, tpr_nb, label='NB (area = %0.3f)' % roc_auc_nb)
plt.plot(fpr_en, tpr_en, label='Ensamble (area = %0.3f)' % roc_auc_en)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curves from the investigated models')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# We see that Tree, KNN, RF and NB models are somewhat worse compared to the other models in AUC.
# Ensamble model is not standing out compared to LogReg and SVM models.
# Nevertheless, ensamble model is expected to be more robust for any future addition of training data.

# %% [markdown]
# ## **Precision-recall curve comparing the models**
#
# Information retrieval researchers define parameters called \textit{recall} and \textit{precision}:
# \begin{equation*}
#     \begin{split}
#         {recall} &= \frac{{number of documents retrieved that are relevant}}{{total number of documents that are relevant}}\\
#         {precision} &= \frac{{number of documents retrieved that are relevant}}{{total number of documents that are retrieved }}
#     \end{split}
# \end{equation*}

# %%
plt.plot([1, 0], [0, 1], 'k--')
plt.plot(recall_lr, precision_lr, label='Log Reg')
plt.plot(recall_SVMrbf, precision_SVMrbf, label='SVM rbf')
plt.plot(recall_SVMlinear, precision_SVMlinear, label='SVM linear')
plt.plot(recall_KNN, precision_KNN, label='KNN')
plt.plot(recall_Tree, precision_Tree, label='Tree')
plt.plot(recall_rf, precision_rf, label='RF')
plt.plot(recall_nb, precision_nb, label='NB')
plt.plot(recall_en, precision_en, label='Ensamble')
plt.title('Precision vs. Recall')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# # **Predictive Outcomes**

# %% [markdown]
# ## **Confusion matrix with ensamble model**
#
# Let us look at the confusion matrix from the ensamble classifier.
# First define a function to plot confusion matrix

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# In the two-class case with classes yes and no, lend or not lend, mark a suspicious
# patch as an oil slick or not, and so on, a single prediction has the four different
# possible outcomes shown in Figure 1.
# The true positives (TP) and true negatives (TN) are correct classifications.
# A false positive (FP) occurs when the outcome is incorrectly predicted as yes
# (or positive) when it is actually no (negative).
# A false negative (FN) occurs when the outcome is incorrectly predicted as neg-
# ative when it is actually positive.

# %%
class_names = test_Y.unique()
cmEnsamble = confusion_matrix(test_Y, predictEnsemble)
plt.grid(False)
plot_confusion_matrix(cmEnsamble, classes=class_names, title='Confusion matrix with ensamble model, without normalization')

# %% [markdown]
# The true positive rate is TP divided by the total number of positives, which is
# TP + FN;
# the false positive rate is FP divided by the total number of negatives, FP +
# TN.
# The overall success rate is the number of correct classifications divided by the
# total number of classifications:
# TP+TN
# TP+TN+FP+FN
# Finally, the error rate is one minus this.

# %% [markdown]
# ## **Classification Report**

# %%
print(metrics.classification_report(test_Y, predictEnsemble))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91        69
#            1       0.91      0.88      0.89        56
#
#     accuracy                           0.90       125
#    macro avg       0.90      0.90      0.90       125
# weighted avg       0.90      0.90      0.90       125

# %% [markdown]
# Looking at the recall scores for 0 (no diabetes) and 1 (having diabetes), the model did well for predicting no diabetes (correct 92% of the time) while did not do that well for predicting diabetes (correct 54% of the time). So, there is room for improving prediction for diabetes.

# %% [markdown]
# # Ensemble with Lsvm, Rsvm, Lr

# %%
linear_svm=svm.SVC(kernel='linear',C=0.1,gamma=10, probability=True)
radial_svm=svm.SVC(kernel='rbf',C=0.1,gamma=10, probability=True)
lr=LogisticRegression(C=0.1)

# %%
ensembleModel=VotingClassifier(estimators=[('Linear_svm',linear_svm), ('Radial_svm', radial_svm), ('Logistic Regression', lr)], 
                                            voting='soft', weights=[1,2,3])

ensembleModel.fit(train_X,train_Y)
predictEnsemble = ensembleModel.predict(test_X)

# %%
print('Accuracy of ensembled model with all the 3 classifiers is:', np.round(ensembleModel.score(test_X,test_Y), 4))
# Out:
# Accuracy of ensembled model with all the 3 classifiers is: 0.832

# %% [markdown]
# # **Cost-sensitive learning**

# %% [markdown]
# ## **Satisfaction prediction using Neural Network with Keras**
#
# Keras is a high level frame work for running neural network applications. It runs tensorflow at the backend.

# %% [markdown]
# Suppose that you artificially increase the number of no instances by a factor of
# 10 and use the resulting dataset for training. If the learning scheme is striving to
# minimize the number of errors, it will come up with a decision structure that is
# biased toward avoiding errors on the no instances, because such errors are effec-
# tively penalized 10-fold. If data with the original proportion of no instances is
# used for testing, fewer errors will be made on these than on yes instances—that
# is, there will be fewer false positives than false negatives—because false posi-
# tives have been weighted 10 times more heavily than false negatives.
#
# Varying the proportion of instances in the training set is a general technique
# for building cost-sensitive classifiers.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# fix random seed for reproducibility
np.random.seed(42)

# %%
train_Y = to_categorical(train_Y, num_classes = 2)
test_Y = to_categorical(test_Y, num_classes = 2)

# %%
# Confirm the train-test split ratio
print(np.shape(train_X))
print(np.shape(train_Y))
print(np.shape(test_X))
print(np.shape(test_Y))
# Out:
# (375, 22)
# (375, 2)
# (125, 22)
# (125, 2)

# %% [markdown]
# ## **1. Create the model using Keras**
#
# input_dim = 8 since we have 22 input variable.
# Here we are using 5 fully connected layers defined by using the Dense class (no particular reason for 5 layers, typically more layers are better). Number of neurons in the layers are the first argument (8, 12, 12, 8, 4 & 1 respecitvely here).
# We use the default weight initialization in Keras which is between 0 to 0.05 assuming "uniform" distribution.
# First 4 layers have "relu" activation and output layer has "sigmoid" activation. Sigmoid on the output layer ensures that we have output between 0 and 1.
#
# We can piece it all together by adding each layer.

# %%
model = Sequential()
model.add(Dense(22, input_dim=22, activation='relu'))
model.add(Dense(12, input_dim=22, activation='relu'))
model.add(Dense(12, input_dim=22, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 22)                506
#
#  dense_1 (Dense)             (None, 12)                276
#
#  dense_2 (Dense)             (None, 12)                156
#
#  dense_3 (Dense)             (None, 8)                 104
#
#  dense_4 (Dense)             (None, 4)                 36
#
#  dense_5 (Dense)             (None, 2)                 10
#
# =================================================================
# Total params: 1,088
# Trainable params: 1,088
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## **2. Compile the model**
#
# Now the model is ready, we can compile it (using tensorflow under the hood or backend) and train it find the best weights for prediction. loss='binary_crossentropy' since the problem is binary classification.
# optimizer='adam' since it is efficient and default default.
# From metrics we collect the accuracy.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## **3. Fit model**
#
# We train the model by calling fit() on training data.
# The number of iteration through the whole training datset is called "epoch". It is set to 150 (higher the better).
# The number of instances that are evaluated before a weight update in the network is performed is the the batch size. It is set to 50 (relatively small, the dataset is also small).
#
# With the model.fit(), we shall also capture the accuracy each epoch.

# %%
epoch = 500
batch_size = 50

history = model.fit(train_X, train_Y, batch_size = batch_size, epochs = epoch, 
          validation_data = (test_X, test_Y), verbose = 2)
# Out:
# Epoch 1/500
# 8/8 - 1s - loss: 0.6956 - accuracy: 0.4987 - val_loss: 0.6870 - val_accuracy: 0.6400 - 1s/epoch - 147ms/step
# Epoch 2/500
# 8/8 - 0s - loss: 0.6832 - accuracy: 0.6507 - val_loss: 0.6759 - val_accuracy: 0.7200 - 39ms/epoch - 5ms/step
# Epoch 3/500
# 8/8 - 0s - loss: 0.6695 - accuracy: 0.7200 - val_loss: 0.6631 - val_accuracy: 0.7360 - 36ms/epoch - 5ms/step
# Epoch 4/500
# 8/8 - 0s - loss: 0.6544 - accuracy: 0.7547 - val_loss: 0.6473 - val_accuracy: 0.7200 - 59ms/epoch - 7ms/step
# Epoch 5/500
# 8/8 - 0s - loss: 0.6360 - accuracy: 0.7733 - val_loss: 0.6305 - val_accuracy: 0.7280 - 56ms/epoch - 7ms/step
# Epoch 6/500
# 8/8 - 0s - loss: 0.6141 - accuracy: 0.7867 - val_loss: 0.6104 - val_accuracy: 0.7520 - 46ms/epoch - 6ms/step
# Epoch 7/500
# 8/8 - 0s - loss: 0.5877 - accuracy: 0.7947 - val_loss: 0.5890 - val_accuracy: 0.7680 - 38ms/epoch - 5ms/step
# Epoch 8/500
# 8/8 - 0s - loss: 0.5576 - accuracy: 0.8133 - val_loss: 0.5642 - val_accuracy: 0.7840 - 57ms/epoch - 7ms/step
# Epoch 9/500
# 8/8 - 0s - loss: 0.5255 - accuracy: 0.8427 - val_loss: 0.5369 - val_accuracy: 0.7760 - 54ms/epoch - 7ms/step
# Epoch 10/500
# 8/8 - 0s - loss: 0.4909 - accuracy: 0.8560 - val_loss: 0.5073 - val_accuracy: 0.7760 - 56ms/epoch - 7ms/step
# Epoch 11/500
# 8/8 - 0s - loss: 0.4551 - accuracy: 0.8667 - val_loss: 0.4801 - val_accuracy: 0.8000 - 36ms/epoch - 5ms/step
# Epoch 12/500
# 8/8 - 0s - loss: 0.4210 - accuracy: 0.8640 - val_loss: 0.4528 - val_accuracy: 0.8160 - 38ms/epoch - 5ms/step
# Epoch 13/500
# 8/8 - 0s - loss: 0.3866 - accuracy: 0.8640 - val_loss: 0.4314 - val_accuracy: 0.8400 - 53ms/epoch - 7ms/step
# Epoch 14/500
# 8/8 - 0s - loss: 0.3592 - accuracy: 0.8720 - val_loss: 0.4126 - val_accuracy: 0.8320 - 36ms/epoch - 5ms/step
# Epoch 15/500
# 8/8 - 0s - loss: 0.3331 - accuracy: 0.8747 - val_loss: 0.4002 - val_accuracy: 0.8400 - 40ms/epoch - 5ms/step
# Epoch 16/500
# 8/8 - 0s - loss: 0.3102 - accuracy: 0.8880 - val_loss: 0.3924 - val_accuracy: 0.8480 - 42ms/epoch - 5ms/step
# Epoch 17/500
# 8/8 - 0s - loss: 0.2939 - accuracy: 0.8960 - val_loss: 0.3874 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 18/500
# 8/8 - 0s - loss: 0.2770 - accuracy: 0.9093 - val_loss: 0.3874 - val_accuracy: 0.8400 - 54ms/epoch - 7ms/step
# Epoch 19/500
# 8/8 - 0s - loss: 0.2622 - accuracy: 0.9173 - val_loss: 0.3870 - val_accuracy: 0.8400 - 53ms/epoch - 7ms/step
# Epoch 20/500
# 8/8 - 0s - loss: 0.2497 - accuracy: 0.9227 - val_loss: 0.3873 - val_accuracy: 0.8320 - 40ms/epoch - 5ms/step
# Epoch 21/500
# 8/8 - 0s - loss: 0.2385 - accuracy: 0.9200 - val_loss: 0.3884 - val_accuracy: 0.8320 - 40ms/epoch - 5ms/step
# Epoch 22/500
# 8/8 - 0s - loss: 0.2289 - accuracy: 0.9200 - val_loss: 0.3904 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 23/500
# 8/8 - 0s - loss: 0.2195 - accuracy: 0.9280 - val_loss: 0.3884 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 24/500
# 8/8 - 0s - loss: 0.2112 - accuracy: 0.9307 - val_loss: 0.3893 - val_accuracy: 0.8320 - 42ms/epoch - 5ms/step
# Epoch 25/500
# 8/8 - 0s - loss: 0.2029 - accuracy: 0.9333 - val_loss: 0.3906 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 26/500
# 8/8 - 0s - loss: 0.1941 - accuracy: 0.9333 - val_loss: 0.3920 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 27/500
# 8/8 - 0s - loss: 0.1871 - accuracy: 0.9360 - val_loss: 0.3945 - val_accuracy: 0.8320 - 46ms/epoch - 6ms/step
# Epoch 28/500
# 8/8 - 0s - loss: 0.1790 - accuracy: 0.9440 - val_loss: 0.3971 - val_accuracy: 0.8320 - 41ms/epoch - 5ms/step
# Epoch 29/500
# 8/8 - 0s - loss: 0.1722 - accuracy: 0.9440 - val_loss: 0.3961 - val_accuracy: 0.8400 - 56ms/epoch - 7ms/step
# Epoch 30/500
# 8/8 - 0s - loss: 0.1665 - accuracy: 0.9493 - val_loss: 0.4020 - val_accuracy: 0.8400 - 38ms/epoch - 5ms/step
# Epoch 31/500
# 8/8 - 0s - loss: 0.1595 - accuracy: 0.9520 - val_loss: 0.3986 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 32/500
# 8/8 - 0s - loss: 0.1530 - accuracy: 0.9520 - val_loss: 0.4026 - val_accuracy: 0.8320 - 39ms/epoch - 5ms/step
# Epoch 33/500
# 8/8 - 0s - loss: 0.1465 - accuracy: 0.9520 - val_loss: 0.4054 - val_accuracy: 0.8400 - 53ms/epoch - 7ms/step
# Epoch 34/500
# 8/8 - 0s - loss: 0.1404 - accuracy: 0.9520 - val_loss: 0.4065 - val_accuracy: 0.8320 - 36ms/epoch - 5ms/step
# Epoch 35/500
# 8/8 - 0s - loss: 0.1344 - accuracy: 0.9547 - val_loss: 0.4113 - val_accuracy: 0.8320 - 56ms/epoch - 7ms/step
# Epoch 36/500
# 8/8 - 0s - loss: 0.1280 - accuracy: 0.9547 - val_loss: 0.4150 - val_accuracy: 0.8320 - 53ms/epoch - 7ms/step
# Epoch 37/500
# 8/8 - 0s - loss: 0.1225 - accuracy: 0.9547 - val_loss: 0.4173 - val_accuracy: 0.8320 - 42ms/epoch - 5ms/step
# Epoch 38/500
# 8/8 - 0s - loss: 0.1168 - accuracy: 0.9547 - val_loss: 0.4220 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 39/500
# 8/8 - 0s - loss: 0.1123 - accuracy: 0.9600 - val_loss: 0.4285 - val_accuracy: 0.8320 - 44ms/epoch - 6ms/step
# Epoch 40/500
# 8/8 - 0s - loss: 0.1083 - accuracy: 0.9600 - val_loss: 0.4324 - val_accuracy: 0.8320 - 56ms/epoch - 7ms/step
# Epoch 41/500
# 8/8 - 0s - loss: 0.1038 - accuracy: 0.9600 - val_loss: 0.4347 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 42/500
# 8/8 - 0s - loss: 0.0995 - accuracy: 0.9653 - val_loss: 0.4399 - val_accuracy: 0.8320 - 56ms/epoch - 7ms/step
# Epoch 43/500
# 8/8 - 0s - loss: 0.0960 - accuracy: 0.9653 - val_loss: 0.4447 - val_accuracy: 0.8400 - 59ms/epoch - 7ms/step
# Epoch 44/500
# 8/8 - 0s - loss: 0.0917 - accuracy: 0.9680 - val_loss: 0.4501 - val_accuracy: 0.8400 - 56ms/epoch - 7ms/step
# Epoch 45/500
# 8/8 - 0s - loss: 0.0875 - accuracy: 0.9680 - val_loss: 0.4565 - val_accuracy: 0.8320 - 62ms/epoch - 8ms/step
# Epoch 46/500
# 8/8 - 0s - loss: 0.0835 - accuracy: 0.9733 - val_loss: 0.4644 - val_accuracy: 0.8320 - 44ms/epoch - 6ms/step
# Epoch 47/500
# 8/8 - 0s - loss: 0.0802 - accuracy: 0.9733 - val_loss: 0.4714 - val_accuracy: 0.8320 - 43ms/epoch - 5ms/step
# Epoch 48/500
# 8/8 - 0s - loss: 0.0749 - accuracy: 0.9760 - val_loss: 0.4767 - val_accuracy: 0.8320 - 57ms/epoch - 7ms/step
# Epoch 49/500
# 8/8 - 0s - loss: 0.0712 - accuracy: 0.9787 - val_loss: 0.4852 - val_accuracy: 0.8320 - 55ms/epoch - 7ms/step
# Epoch 50/500
# 8/8 - 0s - loss: 0.0671 - accuracy: 0.9787 - val_loss: 0.4953 - val_accuracy: 0.8320 - 40ms/epoch - 5ms/step
# Epoch 51/500
# 8/8 - 0s - loss: 0.0635 - accuracy: 0.9813 - val_loss: 0.5023 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 52/500
# 8/8 - 0s - loss: 0.0598 - accuracy: 0.9813 - val_loss: 0.5039 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 53/500
# 8/8 - 0s - loss: 0.0558 - accuracy: 0.9813 - val_loss: 0.5132 - val_accuracy: 0.8320 - 60ms/epoch - 7ms/step
# Epoch 54/500
# 8/8 - 0s - loss: 0.0526 - accuracy: 0.9813 - val_loss: 0.5278 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 55/500
# 8/8 - 0s - loss: 0.0498 - accuracy: 0.9867 - val_loss: 0.5398 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 56/500
# 8/8 - 0s - loss: 0.0469 - accuracy: 0.9893 - val_loss: 0.5368 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 57/500
# 8/8 - 0s - loss: 0.0447 - accuracy: 0.9920 - val_loss: 0.5490 - val_accuracy: 0.8320 - 40ms/epoch - 5ms/step
# Epoch 58/500
# 8/8 - 0s - loss: 0.0413 - accuracy: 0.9920 - val_loss: 0.5546 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 59/500
# 8/8 - 0s - loss: 0.0395 - accuracy: 0.9947 - val_loss: 0.5691 - val_accuracy: 0.8320 - 41ms/epoch - 5ms/step
# Epoch 60/500
# 8/8 - 0s - loss: 0.0376 - accuracy: 0.9920 - val_loss: 0.5852 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 61/500
# 8/8 - 0s - loss: 0.0351 - accuracy: 0.9947 - val_loss: 0.5918 - val_accuracy: 0.8320 - 55ms/epoch - 7ms/step
# Epoch 62/500
# 8/8 - 0s - loss: 0.0334 - accuracy: 0.9947 - val_loss: 0.5970 - val_accuracy: 0.8320 - 36ms/epoch - 5ms/step
# Epoch 63/500
# 8/8 - 0s - loss: 0.0319 - accuracy: 0.9947 - val_loss: 0.6041 - val_accuracy: 0.8320 - 62ms/epoch - 8ms/step
# Epoch 64/500
# 8/8 - 0s - loss: 0.0303 - accuracy: 0.9947 - val_loss: 0.6143 - val_accuracy: 0.8320 - 59ms/epoch - 7ms/step
# Epoch 65/500
# 8/8 - 0s - loss: 0.0286 - accuracy: 0.9947 - val_loss: 0.6177 - val_accuracy: 0.8320 - 58ms/epoch - 7ms/step
# Epoch 66/500
# 8/8 - 0s - loss: 0.0272 - accuracy: 0.9947 - val_loss: 0.6272 - val_accuracy: 0.8320 - 60ms/epoch - 7ms/step
# Epoch 67/500
# 8/8 - 0s - loss: 0.0260 - accuracy: 0.9947 - val_loss: 0.6378 - val_accuracy: 0.8320 - 66ms/epoch - 8ms/step
# Epoch 68/500
# 8/8 - 0s - loss: 0.0248 - accuracy: 0.9947 - val_loss: 0.6482 - val_accuracy: 0.8320 - 59ms/epoch - 7ms/step
# Epoch 69/500
# 8/8 - 0s - loss: 0.0236 - accuracy: 0.9947 - val_loss: 0.6561 - val_accuracy: 0.8320 - 58ms/epoch - 7ms/step
# Epoch 70/500
# 8/8 - 0s - loss: 0.0227 - accuracy: 0.9947 - val_loss: 0.6549 - val_accuracy: 0.8320 - 44ms/epoch - 6ms/step
# Epoch 71/500
# 8/8 - 0s - loss: 0.0218 - accuracy: 0.9947 - val_loss: 0.6644 - val_accuracy: 0.8400 - 64ms/epoch - 8ms/step
# Epoch 72/500
# 8/8 - 0s - loss: 0.0210 - accuracy: 0.9947 - val_loss: 0.6734 - val_accuracy: 0.8320 - 41ms/epoch - 5ms/step
# Epoch 73/500
# 8/8 - 0s - loss: 0.0200 - accuracy: 0.9947 - val_loss: 0.6801 - val_accuracy: 0.8400 - 55ms/epoch - 7ms/step
# Epoch 74/500
# 8/8 - 0s - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.6843 - val_accuracy: 0.8400 - 61ms/epoch - 8ms/step
# Epoch 75/500
# 8/8 - 0s - loss: 0.0185 - accuracy: 0.9947 - val_loss: 0.6917 - val_accuracy: 0.8400 - 45ms/epoch - 6ms/step
# Epoch 76/500
# 8/8 - 0s - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.6991 - val_accuracy: 0.8320 - 46ms/epoch - 6ms/step
# Epoch 77/500
# 8/8 - 0s - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.7082 - val_accuracy: 0.8320 - 40ms/epoch - 5ms/step
# Epoch 78/500
# 8/8 - 0s - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.7149 - val_accuracy: 0.8400 - 58ms/epoch - 7ms/step
# Epoch 79/500
# 8/8 - 0s - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.7137 - val_accuracy: 0.8400 - 64ms/epoch - 8ms/step
# Epoch 80/500
# 8/8 - 0s - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.7182 - val_accuracy: 0.8400 - 44ms/epoch - 5ms/step
# Epoch 81/500
# 8/8 - 0s - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.7278 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 82/500
# 8/8 - 0s - loss: 0.0142 - accuracy: 0.9947 - val_loss: 0.7316 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 83/500
# 8/8 - 0s - loss: 0.0135 - accuracy: 0.9947 - val_loss: 0.7368 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 84/500
# 8/8 - 0s - loss: 0.0129 - accuracy: 0.9947 - val_loss: 0.7382 - val_accuracy: 0.8400 - 49ms/epoch - 6ms/step
# Epoch 85/500
# 8/8 - 0s - loss: 0.0125 - accuracy: 0.9947 - val_loss: 0.7427 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 86/500
# 8/8 - 0s - loss: 0.0119 - accuracy: 0.9947 - val_loss: 0.7481 - val_accuracy: 0.8400 - 42ms/epoch - 5ms/step
# Epoch 87/500
# 8/8 - 0s - loss: 0.0115 - accuracy: 0.9947 - val_loss: 0.7519 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 88/500
# 8/8 - 0s - loss: 0.0109 - accuracy: 0.9947 - val_loss: 0.7611 - val_accuracy: 0.8400 - 60ms/epoch - 7ms/step
# Epoch 89/500
# 8/8 - 0s - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.7672 - val_accuracy: 0.8400 - 59ms/epoch - 7ms/step
# Epoch 90/500
# 8/8 - 0s - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.7719 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 91/500
# 8/8 - 0s - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.7776 - val_accuracy: 0.8480 - 36ms/epoch - 5ms/step
# Epoch 92/500
# 8/8 - 0s - loss: 0.0094 - accuracy: 0.9973 - val_loss: 0.7753 - val_accuracy: 0.8480 - 60ms/epoch - 8ms/step
# Epoch 93/500
# 8/8 - 0s - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.7802 - val_accuracy: 0.8480 - 42ms/epoch - 5ms/step
# Epoch 94/500
# 8/8 - 0s - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.7877 - val_accuracy: 0.8480 - 54ms/epoch - 7ms/step
# Epoch 95/500
# 8/8 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.7988 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 96/500
# 8/8 - 0s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.7937 - val_accuracy: 0.8400 - 45ms/epoch - 6ms/step
# Epoch 97/500
# 8/8 - 0s - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.7993 - val_accuracy: 0.8400 - 38ms/epoch - 5ms/step
# Epoch 98/500
# 8/8 - 0s - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.8067 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 99/500
# 8/8 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.8152 - val_accuracy: 0.8400 - 39ms/epoch - 5ms/step
# Epoch 100/500
# 8/8 - 0s - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.8206 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 101/500
# 8/8 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.8287 - val_accuracy: 0.8400 - 43ms/epoch - 5ms/step
# Epoch 102/500
# 8/8 - 0s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.8341 - val_accuracy: 0.8400 - 38ms/epoch - 5ms/step
# Epoch 103/500
# 8/8 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.8414 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 104/500
# 8/8 - 0s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.8468 - val_accuracy: 0.8480 - 52ms/epoch - 7ms/step
# Epoch 105/500
# 8/8 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.8541 - val_accuracy: 0.8480 - 60ms/epoch - 8ms/step
# Epoch 106/500
# 8/8 - 0s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.8571 - val_accuracy: 0.8480 - 61ms/epoch - 8ms/step
# Epoch 107/500
# 8/8 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.8641 - val_accuracy: 0.8480 - 36ms/epoch - 4ms/step
# Epoch 108/500
# 8/8 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.8697 - val_accuracy: 0.8480 - 45ms/epoch - 6ms/step
# Epoch 109/500
# 8/8 - 0s - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.8736 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 110/500
# 8/8 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.8788 - val_accuracy: 0.8480 - 54ms/epoch - 7ms/step
# Epoch 111/500
# 8/8 - 0s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.8848 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 112/500
# 8/8 - 0s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.8914 - val_accuracy: 0.8480 - 36ms/epoch - 5ms/step
# Epoch 113/500
# 8/8 - 0s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.8976 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 114/500
# 8/8 - 0s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.9032 - val_accuracy: 0.8480 - 53ms/epoch - 7ms/step
# Epoch 115/500
# 8/8 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9049 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 116/500
# 8/8 - 0s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9128 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 117/500
# 8/8 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.9175 - val_accuracy: 0.8480 - 54ms/epoch - 7ms/step
# Epoch 118/500
# 8/8 - 0s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9226 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 119/500
# 8/8 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9253 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 120/500
# 8/8 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9333 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 121/500
# 8/8 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.9400 - val_accuracy: 0.8480 - 43ms/epoch - 5ms/step
# Epoch 122/500
# 8/8 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9445 - val_accuracy: 0.8480 - 54ms/epoch - 7ms/step
# Epoch 123/500
# 8/8 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9483 - val_accuracy: 0.8480 - 44ms/epoch - 6ms/step
# Epoch 124/500
# 8/8 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9546 - val_accuracy: 0.8480 - 44ms/epoch - 6ms/step
# Epoch 125/500
# 8/8 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.9608 - val_accuracy: 0.8480 - 44ms/epoch - 6ms/step
# Epoch 126/500
# 8/8 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9619 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 127/500
# 8/8 - 0s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.9663 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 128/500
# 8/8 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9703 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 129/500
# 8/8 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9762 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 130/500
# 8/8 - 0s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.9783 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 131/500
# 8/8 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9826 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 132/500
# 8/8 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.9869 - val_accuracy: 0.8480 - 43ms/epoch - 5ms/step
# Epoch 133/500
# 8/8 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9904 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 134/500
# 8/8 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9950 - val_accuracy: 0.8480 - 35ms/epoch - 4ms/step
# Epoch 135/500
# 8/8 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9985 - val_accuracy: 0.8480 - 55ms/epoch - 7ms/step
# Epoch 136/500
# 8/8 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0040 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 137/500
# 8/8 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0052 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 138/500
# 8/8 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0099 - val_accuracy: 0.8480 - 60ms/epoch - 8ms/step
# Epoch 139/500
# 8/8 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0161 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 140/500
# 8/8 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0187 - val_accuracy: 0.8480 - 59ms/epoch - 7ms/step
# Epoch 141/500
# 8/8 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0228 - val_accuracy: 0.8480 - 57ms/epoch - 7ms/step
# Epoch 142/500
# 8/8 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0273 - val_accuracy: 0.8480 - 58ms/epoch - 7ms/step
# Epoch 143/500
# 8/8 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.0288 - val_accuracy: 0.8480 - 57ms/epoch - 7ms/step
# Epoch 144/500
# 8/8 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0332 - val_accuracy: 0.8480 - 63ms/epoch - 8ms/step
# Epoch 145/500
# 8/8 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0389 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 146/500
# 8/8 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0424 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 147/500
# 8/8 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0456 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 148/500
# 8/8 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0493 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 149/500
# 8/8 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0482 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 150/500
# 8/8 - 0s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0528 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 151/500
# 8/8 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.0573 - val_accuracy: 0.8480 - 36ms/epoch - 5ms/step
# Epoch 152/500
# 8/8 - 0s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.0608 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 153/500
# 8/8 - 0s - loss: 9.8627e-04 - accuracy: 1.0000 - val_loss: 1.0635 - val_accuracy: 0.8480 - 35ms/epoch - 4ms/step
# Epoch 154/500
# 8/8 - 0s - loss: 9.7375e-04 - accuracy: 1.0000 - val_loss: 1.0650 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 155/500
# 8/8 - 0s - loss: 9.4784e-04 - accuracy: 1.0000 - val_loss: 1.0695 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 156/500
# 8/8 - 0s - loss: 9.2539e-04 - accuracy: 1.0000 - val_loss: 1.0743 - val_accuracy: 0.8480 - 59ms/epoch - 7ms/step
# Epoch 157/500
# 8/8 - 0s - loss: 9.0207e-04 - accuracy: 1.0000 - val_loss: 1.0783 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 158/500
# 8/8 - 0s - loss: 8.8151e-04 - accuracy: 1.0000 - val_loss: 1.0832 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 159/500
# 8/8 - 0s - loss: 8.6400e-04 - accuracy: 1.0000 - val_loss: 1.0840 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 160/500
# 8/8 - 0s - loss: 8.4640e-04 - accuracy: 1.0000 - val_loss: 1.0859 - val_accuracy: 0.8480 - 53ms/epoch - 7ms/step
# Epoch 161/500
# 8/8 - 0s - loss: 8.2799e-04 - accuracy: 1.0000 - val_loss: 1.0898 - val_accuracy: 0.8480 - 55ms/epoch - 7ms/step
# Epoch 162/500
# 8/8 - 0s - loss: 8.1530e-04 - accuracy: 1.0000 - val_loss: 1.0934 - val_accuracy: 0.8480 - 60ms/epoch - 8ms/step
# Epoch 163/500
# 8/8 - 0s - loss: 7.9564e-04 - accuracy: 1.0000 - val_loss: 1.0970 - val_accuracy: 0.8480 - 60ms/epoch - 7ms/step
# Epoch 164/500
# 8/8 - 0s - loss: 7.8454e-04 - accuracy: 1.0000 - val_loss: 1.1003 - val_accuracy: 0.8480 - 58ms/epoch - 7ms/step
# Epoch 165/500
# 8/8 - 0s - loss: 7.6867e-04 - accuracy: 1.0000 - val_loss: 1.1038 - val_accuracy: 0.8480 - 66ms/epoch - 8ms/step
# Epoch 166/500
# 8/8 - 0s - loss: 7.5219e-04 - accuracy: 1.0000 - val_loss: 1.1083 - val_accuracy: 0.8480 - 59ms/epoch - 7ms/step
# Epoch 167/500
# 8/8 - 0s - loss: 7.3596e-04 - accuracy: 1.0000 - val_loss: 1.1119 - val_accuracy: 0.8480 - 75ms/epoch - 9ms/step
# Epoch 168/500
# 8/8 - 0s - loss: 7.2651e-04 - accuracy: 1.0000 - val_loss: 1.1148 - val_accuracy: 0.8480 - 63ms/epoch - 8ms/step
# Epoch 169/500
# 8/8 - 0s - loss: 7.1264e-04 - accuracy: 1.0000 - val_loss: 1.1163 - val_accuracy: 0.8480 - 57ms/epoch - 7ms/step
# Epoch 170/500
# 8/8 - 0s - loss: 6.9856e-04 - accuracy: 1.0000 - val_loss: 1.1195 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 171/500
# 8/8 - 0s - loss: 6.8655e-04 - accuracy: 1.0000 - val_loss: 1.1243 - val_accuracy: 0.8480 - 52ms/epoch - 6ms/step
# Epoch 172/500
# 8/8 - 0s - loss: 6.7665e-04 - accuracy: 1.0000 - val_loss: 1.1251 - val_accuracy: 0.8480 - 43ms/epoch - 5ms/step
# Epoch 173/500
# 8/8 - 0s - loss: 6.6326e-04 - accuracy: 1.0000 - val_loss: 1.1289 - val_accuracy: 0.8480 - 62ms/epoch - 8ms/step
# Epoch 174/500
# 8/8 - 0s - loss: 6.5004e-04 - accuracy: 1.0000 - val_loss: 1.1323 - val_accuracy: 0.8480 - 44ms/epoch - 5ms/step
# Epoch 175/500
# 8/8 - 0s - loss: 6.4177e-04 - accuracy: 1.0000 - val_loss: 1.1345 - val_accuracy: 0.8480 - 62ms/epoch - 8ms/step
# Epoch 176/500
# 8/8 - 0s - loss: 6.2945e-04 - accuracy: 1.0000 - val_loss: 1.1359 - val_accuracy: 0.8480 - 60ms/epoch - 8ms/step
# Epoch 177/500
# 8/8 - 0s - loss: 6.2058e-04 - accuracy: 1.0000 - val_loss: 1.1395 - val_accuracy: 0.8480 - 64ms/epoch - 8ms/step
# Epoch 178/500
# 8/8 - 0s - loss: 6.0895e-04 - accuracy: 1.0000 - val_loss: 1.1423 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 179/500
# 8/8 - 0s - loss: 5.9741e-04 - accuracy: 1.0000 - val_loss: 1.1465 - val_accuracy: 0.8480 - 62ms/epoch - 8ms/step
# Epoch 180/500
# 8/8 - 0s - loss: 5.8567e-04 - accuracy: 1.0000 - val_loss: 1.1492 - val_accuracy: 0.8480 - 36ms/epoch - 5ms/step
# Epoch 181/500
# 8/8 - 0s - loss: 5.7584e-04 - accuracy: 1.0000 - val_loss: 1.1520 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 182/500
# 8/8 - 0s - loss: 5.6684e-04 - accuracy: 1.0000 - val_loss: 1.1550 - val_accuracy: 0.8480 - 49ms/epoch - 6ms/step
# Epoch 183/500
# 8/8 - 0s - loss: 5.5871e-04 - accuracy: 1.0000 - val_loss: 1.1572 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 184/500
# 8/8 - 0s - loss: 5.5009e-04 - accuracy: 1.0000 - val_loss: 1.1580 - val_accuracy: 0.8480 - 35ms/epoch - 4ms/step
# Epoch 185/500
# 8/8 - 0s - loss: 5.4412e-04 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 186/500
# 8/8 - 0s - loss: 5.3453e-04 - accuracy: 1.0000 - val_loss: 1.1648 - val_accuracy: 0.8480 - 59ms/epoch - 7ms/step
# Epoch 187/500
# 8/8 - 0s - loss: 5.2475e-04 - accuracy: 1.0000 - val_loss: 1.1678 - val_accuracy: 0.8480 - 45ms/epoch - 6ms/step
# Epoch 188/500
# 8/8 - 0s - loss: 5.1631e-04 - accuracy: 1.0000 - val_loss: 1.1703 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 189/500
# 8/8 - 0s - loss: 5.0690e-04 - accuracy: 1.0000 - val_loss: 1.1737 - val_accuracy: 0.8480 - 43ms/epoch - 5ms/step
# Epoch 190/500
# 8/8 - 0s - loss: 4.9898e-04 - accuracy: 1.0000 - val_loss: 1.1757 - val_accuracy: 0.8480 - 53ms/epoch - 7ms/step
# Epoch 191/500
# 8/8 - 0s - loss: 4.9154e-04 - accuracy: 1.0000 - val_loss: 1.1790 - val_accuracy: 0.8480 - 55ms/epoch - 7ms/step
# Epoch 192/500
# 8/8 - 0s - loss: 4.8493e-04 - accuracy: 1.0000 - val_loss: 1.1810 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 193/500
# 8/8 - 0s - loss: 4.7902e-04 - accuracy: 1.0000 - val_loss: 1.1833 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 194/500
# 8/8 - 0s - loss: 4.7189e-04 - accuracy: 1.0000 - val_loss: 1.1863 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 195/500
# 8/8 - 0s - loss: 4.6393e-04 - accuracy: 1.0000 - val_loss: 1.1884 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 196/500
# 8/8 - 0s - loss: 4.5596e-04 - accuracy: 1.0000 - val_loss: 1.1903 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 197/500
# 8/8 - 0s - loss: 4.4812e-04 - accuracy: 1.0000 - val_loss: 1.1923 - val_accuracy: 0.8480 - 58ms/epoch - 7ms/step
# Epoch 198/500
# 8/8 - 0s - loss: 4.4278e-04 - accuracy: 1.0000 - val_loss: 1.1945 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 199/500
# 8/8 - 0s - loss: 4.3637e-04 - accuracy: 1.0000 - val_loss: 1.1974 - val_accuracy: 0.8480 - 58ms/epoch - 7ms/step
# Epoch 200/500
# 8/8 - 0s - loss: 4.3019e-04 - accuracy: 1.0000 - val_loss: 1.2002 - val_accuracy: 0.8480 - 64ms/epoch - 8ms/step
# Epoch 201/500
# 8/8 - 0s - loss: 4.2531e-04 - accuracy: 1.0000 - val_loss: 1.2033 - val_accuracy: 0.8480 - 47ms/epoch - 6ms/step
# Epoch 202/500
# 8/8 - 0s - loss: 4.1805e-04 - accuracy: 1.0000 - val_loss: 1.2044 - val_accuracy: 0.8480 - 60ms/epoch - 7ms/step
# Epoch 203/500
# 8/8 - 0s - loss: 4.1252e-04 - accuracy: 1.0000 - val_loss: 1.2066 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 204/500
# 8/8 - 0s - loss: 4.0632e-04 - accuracy: 1.0000 - val_loss: 1.2084 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 205/500
# 8/8 - 0s - loss: 4.0126e-04 - accuracy: 1.0000 - val_loss: 1.2107 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 206/500
# 8/8 - 0s - loss: 3.9542e-04 - accuracy: 1.0000 - val_loss: 1.2146 - val_accuracy: 0.8480 - 53ms/epoch - 7ms/step
# Epoch 207/500
# 8/8 - 0s - loss: 3.8936e-04 - accuracy: 1.0000 - val_loss: 1.2163 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 208/500
# 8/8 - 0s - loss: 3.8433e-04 - accuracy: 1.0000 - val_loss: 1.2183 - val_accuracy: 0.8480 - 62ms/epoch - 8ms/step
# Epoch 209/500
# 8/8 - 0s - loss: 3.7792e-04 - accuracy: 1.0000 - val_loss: 1.2205 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 210/500
# 8/8 - 0s - loss: 3.7296e-04 - accuracy: 1.0000 - val_loss: 1.2237 - val_accuracy: 0.8480 - 37ms/epoch - 5ms/step
# Epoch 211/500
# 8/8 - 0s - loss: 3.6763e-04 - accuracy: 1.0000 - val_loss: 1.2260 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 212/500
# 8/8 - 0s - loss: 3.6250e-04 - accuracy: 1.0000 - val_loss: 1.2276 - val_accuracy: 0.8480 - 57ms/epoch - 7ms/step
# Epoch 213/500
# 8/8 - 0s - loss: 3.5819e-04 - accuracy: 1.0000 - val_loss: 1.2292 - val_accuracy: 0.8480 - 54ms/epoch - 7ms/step
# Epoch 214/500
# 8/8 - 0s - loss: 3.5328e-04 - accuracy: 1.0000 - val_loss: 1.2320 - val_accuracy: 0.8480 - 43ms/epoch - 5ms/step
# Epoch 215/500
# 8/8 - 0s - loss: 3.4835e-04 - accuracy: 1.0000 - val_loss: 1.2344 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 216/500
# 8/8 - 0s - loss: 3.4366e-04 - accuracy: 1.0000 - val_loss: 1.2372 - val_accuracy: 0.8480 - 36ms/epoch - 4ms/step
# Epoch 217/500
# 8/8 - 0s - loss: 3.3999e-04 - accuracy: 1.0000 - val_loss: 1.2394 - val_accuracy: 0.8480 - 35ms/epoch - 4ms/step
# Epoch 218/500
# 8/8 - 0s - loss: 3.3730e-04 - accuracy: 1.0000 - val_loss: 1.2368 - val_accuracy: 0.8480 - 42ms/epoch - 5ms/step
# Epoch 219/500
# 8/8 - 0s - loss: 3.3236e-04 - accuracy: 1.0000 - val_loss: 1.2387 - val_accuracy: 0.8480 - 39ms/epoch - 5ms/step
# Epoch 220/500
# 8/8 - 0s - loss: 3.2760e-04 - accuracy: 1.0000 - val_loss: 1.2415 - val_accuracy: 0.8480 - 40ms/epoch - 5ms/step
# Epoch 221/500
# 8/8 - 0s - loss: 3.2173e-04 - accuracy: 1.0000 - val_loss: 1.2454 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 222/500
# 8/8 - 0s - loss: 3.1694e-04 - accuracy: 1.0000 - val_loss: 1.2488 - val_accuracy: 0.8480 - 48ms/epoch - 6ms/step
# Epoch 223/500
# 8/8 - 0s - loss: 3.1242e-04 - accuracy: 1.0000 - val_loss: 1.2517 - val_accuracy: 0.8480 - 38ms/epoch - 5ms/step
# Epoch 224/500
# 8/8 - 0s - loss: 3.0857e-04 - accuracy: 1.0000 - val_loss: 1.2542 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 225/500
# 8/8 - 0s - loss: 3.0487e-04 - accuracy: 1.0000 - val_loss: 1.2541 - val_accuracy: 0.8480 - 62ms/epoch - 8ms/step
# Epoch 226/500
# 8/8 - 0s - loss: 3.0010e-04 - accuracy: 1.0000 - val_loss: 1.2566 - val_accuracy: 0.8480 - 56ms/epoch - 7ms/step
# Epoch 227/500
# 8/8 - 0s - loss: 2.9591e-04 - accuracy: 1.0000 - val_loss: 1.2588 - val_accuracy: 0.8400 - 40ms/epoch - 5ms/step
# Epoch 228/500
# 8/8 - 0s - loss: 2.9203e-04 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 229/500
# 8/8 - 0s - loss: 2.8809e-04 - accuracy: 1.0000 - val_loss: 1.2635 - val_accuracy: 0.8480 - 57ms/epoch - 7ms/step
# Epoch 230/500
# 8/8 - 0s - loss: 2.8392e-04 - accuracy: 1.0000 - val_loss: 1.2650 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 231/500
# 8/8 - 0s - loss: 2.8080e-04 - accuracy: 1.0000 - val_loss: 1.2674 - val_accuracy: 0.8480 - 59ms/epoch - 7ms/step
# Epoch 232/500
# 8/8 - 0s - loss: 2.7730e-04 - accuracy: 1.0000 - val_loss: 1.2690 - val_accuracy: 0.8480 - 41ms/epoch - 5ms/step
# Epoch 233/500
# 8/8 - 0s - loss: 2.7400e-04 - accuracy: 1.0000 - val_loss: 1.2716 - val_accuracy: 0.8400 - 35ms/epoch - 4ms/step
# Epoch 234/500
# 8/8 - 0s - loss: 2.7062e-04 - accuracy: 1.0000 - val_loss: 1.2734 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 235/500
# 8/8 - 0s - loss: 2.6710e-04 - accuracy: 1.0000 - val_loss: 1.2757 - val_accuracy: 0.8400 - 58ms/epoch - 7ms/step
# Epoch 236/500
# 8/8 - 0s - loss: 2.6409e-04 - accuracy: 1.0000 - val_loss: 1.2776 - val_accuracy: 0.8400 - 46ms/epoch - 6ms/step
# Epoch 237/500
# 8/8 - 0s - loss: 2.6153e-04 - accuracy: 1.0000 - val_loss: 1.2796 - val_accuracy: 0.8400 - 54ms/epoch - 7ms/step
# Epoch 238/500
# 8/8 - 0s - loss: 2.5932e-04 - accuracy: 1.0000 - val_loss: 1.2796 - val_accuracy: 0.8400 - 60ms/epoch - 8ms/step
# Epoch 239/500
# 8/8 - 0s - loss: 2.5668e-04 - accuracy: 1.0000 - val_loss: 1.2812 - val_accuracy: 0.8400 - 62ms/epoch - 8ms/step
# Epoch 240/500
# 8/8 - 0s - loss: 2.5353e-04 - accuracy: 1.0000 - val_loss: 1.2830 - val_accuracy: 0.8400 - 61ms/epoch - 8ms/step
# Epoch 241/500
# 8/8 - 0s - loss: 2.4962e-04 - accuracy: 1.0000 - val_loss: 1.2850 - val_accuracy: 0.8400 - 51ms/epoch - 6ms/step
# Epoch 242/500
# 8/8 - 0s - loss: 2.4606e-04 - accuracy: 1.0000 - val_loss: 1.2877 - val_accuracy: 0.8400 - 63ms/epoch - 8ms/step
# Epoch 243/500
# 8/8 - 0s - loss: 2.4303e-04 - accuracy: 1.0000 - val_loss: 1.2901 - val_accuracy: 0.8400 - 48ms/epoch - 6ms/step
# Epoch 244/500
# 8/8 - 0s - loss: 2.4000e-04 - accuracy: 1.0000 - val_loss: 1.2923 - val_accuracy: 0.8400 - 45ms/epoch - 6ms/step
# Epoch 245/500
# 8/8 - 0s - loss: 2.3724e-04 - accuracy: 1.0000 - val_loss: 1.2932 - val_accuracy: 0.8400 - 50ms/epoch - 6ms/step
# Epoch 246/500
# 8/8 - 0s - loss: 2.3480e-04 - accuracy: 1.0000 - val_loss: 1.2958 - val_accuracy: 0.8400 - 62ms/epoch - 8ms/step
# Epoch 247/500
# 8/8 - 0s - loss: 2.3200e-04 - accuracy: 1.0000 - val_loss: 1.2973 - val_accuracy: 0.8400 - 59ms/epoch - 7ms/step
# Epoch 248/500
# 8/8 - 0s - loss: 2.2985e-04 - accuracy: 1.0000 - val_loss: 1.2988 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 249/500
# 8/8 - 0s - loss: 2.2691e-04 - accuracy: 1.0000 - val_loss: 1.3008 - val_accuracy: 0.8400 - 44ms/epoch - 5ms/step
# Epoch 250/500
# 8/8 - 0s - loss: 2.2409e-04 - accuracy: 1.0000 - val_loss: 1.3021 - val_accuracy: 0.8400 - 45ms/epoch - 6ms/step
# Epoch 251/500
# 8/8 - 0s - loss: 2.2140e-04 - accuracy: 1.0000 - val_loss: 1.3034 - val_accuracy: 0.8400 - 56ms/epoch - 7ms/step
# Epoch 252/500
# 8/8 - 0s - loss: 2.1955e-04 - accuracy: 1.0000 - val_loss: 1.3042 - val_accuracy: 0.8400 - 44ms/epoch - 5ms/step
# Epoch 253/500
# 8/8 - 0s - loss: 2.1635e-04 - accuracy: 1.0000 - val_loss: 1.3072 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 254/500
# 8/8 - 0s - loss: 2.1396e-04 - accuracy: 1.0000 - val_loss: 1.3097 - val_accuracy: 0.8400 - 42ms/epoch - 5ms/step
# Epoch 255/500
# 8/8 - 0s - loss: 2.1142e-04 - accuracy: 1.0000 - val_loss: 1.3113 - val_accuracy: 0.8400 - 59ms/epoch - 7ms/step
# Epoch 256/500
# 8/8 - 0s - loss: 2.0917e-04 - accuracy: 1.0000 - val_loss: 1.3131 - val_accuracy: 0.8400 - 49ms/epoch - 6ms/step
# Epoch 257/500
# 8/8 - 0s - loss: 2.0702e-04 - accuracy: 1.0000 - val_loss: 1.3146 - val_accuracy: 0.8400 - 40ms/epoch - 5ms/step
# Epoch 258/500
# 8/8 - 0s - loss: 2.0482e-04 - accuracy: 1.0000 - val_loss: 1.3162 - val_accuracy: 0.8400 - 62ms/epoch - 8ms/step
# Epoch 259/500
# 8/8 - 0s - loss: 2.0260e-04 - accuracy: 1.0000 - val_loss: 1.3187 - val_accuracy: 0.8400 - 40ms/epoch - 5ms/step
# Epoch 260/500
# 8/8 - 0s - loss: 2.0042e-04 - accuracy: 1.0000 - val_loss: 1.3195 - val_accuracy: 0.8400 - 47ms/epoch - 6ms/step
# Epoch 261/500
# 8/8 - 0s - loss: 1.9816e-04 - accuracy: 1.0000 - val_loss: 1.3218 - val_accuracy: 0.8400 - 40ms/epoch - 5ms/step
# Epoch 262/500
# 8/8 - 0s - loss: 1.9624e-04 - accuracy: 1.0000 - val_loss: 1.3229 - val_accuracy: 0.8400 - 56ms/epoch - 7ms/step
# Epoch 263/500
# 8/8 - 0s - loss: 1.9417e-04 - accuracy: 1.0000 - val_loss: 1.3258 - val_accuracy: 0.8400 - 54ms/epoch - 7ms/step
# Epoch 264/500
# 8/8 - 0s - loss: 1.9180e-04 - accuracy: 1.0000 - val_loss: 1.3266 - val_accuracy: 0.8400 - 38ms/epoch - 5ms/step
# Epoch 265/500
# 8/8 - 0s - loss: 1.8962e-04 - accuracy: 1.0000 - val_loss: 1.3285 - val_accuracy: 0.8400 - 46ms/epoch - 6ms/step
# Epoch 266/500
# 8/8 - 0s - loss: 1.8777e-04 - accuracy: 1.0000 - val_loss: 1.3303 - val_accuracy: 0.8400 - 60ms/epoch - 7ms/step
# Epoch 267/500
# 8/8 - 0s - loss: 1.8548e-04 - accuracy: 1.0000 - val_loss: 1.3324 - val_accuracy: 0.8400 - 56ms/epoch - 7ms/step
# Epoch 268/500
# 8/8 - 0s - loss: 1.8324e-04 - accuracy: 1.0000 - val_loss: 1.3333 - val_accuracy: 0.8400 - 39ms/epoch - 5ms/step
# Epoch 269/500
# 8/8 - 0s - loss: 1.8158e-04 - accuracy: 1.0000 - val_loss: 1.3346 - val_accuracy: 0.8400 - 48ms/epoch - 6ms/step
# Epoch 270/500
# 8/8 - 0s - loss: 1.7899e-04 - accuracy: 1.0000 - val_loss: 1.3353 - val_accuracy: 0.8400 - 42ms/epoch - 5ms/step
# Epoch 271/500
# 8/8 - 0s - loss: 1.7746e-04 - accuracy: 1.0000 - val_loss: 1.3367 - val_accuracy: 0.8400 - 44ms/epoch - 5ms/step
# Epoch 272/500
# 8/8 - 0s - loss: 1.7515e-04 - accuracy: 1.0000 - val_loss: 1.3391 - val_accuracy: 0.8400 - 44ms/epoch - 6ms/step
# Epoch 273/500
# 8/8 - 0s - loss: 1.7323e-04 - accuracy: 1.0000 - val_loss: 1.3413 - val_accuracy: 0.8400 - 43ms/epoch - 5ms/step
# Epoch 274/500
# 8/8 - 0s - loss: 1.7175e-04 - accuracy: 1.0000 - val_loss: 1.3422 - val_accuracy: 0.8400 - 37ms/epoch - 5ms/step
# Epoch 275/500
# 8/8 - 0s - loss: 1.6951e-04 - accuracy: 1.0000 - val_loss: 1.3446 - val_accuracy: 0.8400 - 54ms/epoch - 7ms/step
# Epoch 276/500
# 8/8 - 0s - loss: 1.6783e-04 - accuracy: 1.0000 - val_loss: 1.3469 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 277/500
# 8/8 - 0s - loss: 1.6626e-04 - accuracy: 1.0000 - val_loss: 1.3488 - val_accuracy: 0.8320 - 44ms/epoch - 6ms/step
# Epoch 278/500
# 8/8 - 0s - loss: 1.6431e-04 - accuracy: 1.0000 - val_loss: 1.3497 - val_accuracy: 0.8320 - 43ms/epoch - 5ms/step
# Epoch 279/500
# 8/8 - 0s - loss: 1.6263e-04 - accuracy: 1.0000 - val_loss: 1.3508 - val_accuracy: 0.8320 - 44ms/epoch - 6ms/step
# Epoch 280/500
# 8/8 - 0s - loss: 1.6116e-04 - accuracy: 1.0000 - val_loss: 1.3527 - val_accuracy: 0.8320 - 73ms/epoch - 9ms/step
# Epoch 281/500
# 8/8 - 0s - loss: 1.5928e-04 - accuracy: 1.0000 - val_loss: 1.3546 - val_accuracy: 0.8400 - 61ms/epoch - 8ms/step
# Epoch 282/500
# 8/8 - 0s - loss: 1.5755e-04 - accuracy: 1.0000 - val_loss: 1.3565 - val_accuracy: 0.8400 - 57ms/epoch - 7ms/step
# Epoch 283/500
# 8/8 - 0s - loss: 1.5679e-04 - accuracy: 1.0000 - val_loss: 1.3585 - val_accuracy: 0.8320 - 45ms/epoch - 6ms/step
# Epoch 284/500
# 8/8 - 0s - loss: 1.5465e-04 - accuracy: 1.0000 - val_loss: 1.3590 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 285/500
# 8/8 - 0s - loss: 1.5312e-04 - accuracy: 1.0000 - val_loss: 1.3607 - val_accuracy: 0.8400 - 39ms/epoch - 5ms/step
# Epoch 286/500
# 8/8 - 0s - loss: 1.5170e-04 - accuracy: 1.0000 - val_loss: 1.3625 - val_accuracy: 0.8400 - 41ms/epoch - 5ms/step
# Epoch 287/500
# 8/8 - 0s - loss: 1.5001e-04 - accuracy: 1.0000 - val_loss: 1.3634 - val_accuracy: 0.8320 - 45ms/epoch - 6ms/step
# Epoch 288/500
# 8/8 - 0s - loss: 1.4844e-04 - accuracy: 1.0000 - val_loss: 1.3650 - val_accuracy: 0.8320 - 46ms/epoch - 6ms/step
# Epoch 289/500
# 8/8 - 0s - loss: 1.4714e-04 - accuracy: 1.0000 - val_loss: 1.3666 - val_accuracy: 0.8320 - 61ms/epoch - 8ms/step
# Epoch 290/500
# 8/8 - 0s - loss: 1.4562e-04 - accuracy: 1.0000 - val_loss: 1.3686 - val_accuracy: 0.8320 - 63ms/epoch - 8ms/step
# Epoch 291/500
# 8/8 - 0s - loss: 1.4415e-04 - accuracy: 1.0000 - val_loss: 1.3703 - val_accuracy: 0.8320 - 44ms/epoch - 5ms/step
# Epoch 292/500
# 8/8 - 0s - loss: 1.4303e-04 - accuracy: 1.0000 - val_loss: 1.3716 - val_accuracy: 0.8320 - 45ms/epoch - 6ms/step
# Epoch 293/500
# 8/8 - 0s - loss: 1.4164e-04 - accuracy: 1.0000 - val_loss: 1.3726 - val_accuracy: 0.8320 - 50ms/epoch - 6ms/step
# Epoch 294/500
# 8/8 - 0s - loss: 1.4013e-04 - accuracy: 1.0000 - val_loss: 1.3742 - val_accuracy: 0.8320 - 47ms/epoch - 6ms/step
# Epoch 295/500
# 8/8 - 0s - loss: 1.3877e-04 - accuracy: 1.0000 - val_loss: 1.3749 - val_accuracy: 0.8320 - 61ms/epoch - 8ms/step
# Epoch 296/500
# 8/8 - 0s - loss: 1.3738e-04 - accuracy: 1.0000 - val_loss: 1.3766 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 297/500
# 8/8 - 0s - loss: 1.3617e-04 - accuracy: 1.0000 - val_loss: 1.3784 - val_accuracy: 0.8320 - 43ms/epoch - 5ms/step
# Epoch 298/500
# 8/8 - 0s - loss: 1.3476e-04 - accuracy: 1.0000 - val_loss: 1.3803 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 299/500
# 8/8 - 0s - loss: 1.3352e-04 - accuracy: 1.0000 - val_loss: 1.3821 - val_accuracy: 0.8320 - 53ms/epoch - 7ms/step
# Epoch 300/500
# 8/8 - 0s - loss: 1.3238e-04 - accuracy: 1.0000 - val_loss: 1.3831 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 301/500
# 8/8 - 0s - loss: 1.3097e-04 - accuracy: 1.0000 - val_loss: 1.3847 - val_accuracy: 0.8320 - 56ms/epoch - 7ms/step
# Epoch 302/500
# 8/8 - 0s - loss: 1.2984e-04 - accuracy: 1.0000 - val_loss: 1.3855 - val_accuracy: 0.8240 - 36ms/epoch - 5ms/step
# Epoch 303/500
# 8/8 - 0s - loss: 1.2853e-04 - accuracy: 1.0000 - val_loss: 1.3867 - val_accuracy: 0.8320 - 37ms/epoch - 5ms/step
# Epoch 304/500
# 8/8 - 0s - loss: 1.2719e-04 - accuracy: 1.0000 - val_loss: 1.3888 - val_accuracy: 0.8320 - 38ms/epoch - 5ms/step
# Epoch 305/500
# 8/8 - 0s - loss: 1.2622e-04 - accuracy: 1.0000 - val_loss: 1.3907 - val_accuracy: 0.8320 - 39ms/epoch - 5ms/step
# Epoch 306/500
# 8/8 - 0s - loss: 1.2515e-04 - accuracy: 1.0000 - val_loss: 1.3918 - val_accuracy: 0.8320 - 61ms/epoch - 8ms/step
# Epoch 307/500
# 8/8 - 0s - loss: 1.2390e-04 - accuracy: 1.0000 - val_loss: 1.3934 - val_accuracy: 0.8320 - 62ms/epoch - 8ms/step
# Epoch 308/500
# 8/8 - 0s - loss: 1.2307e-04 - accuracy: 1.0000 - val_loss: 1.3943 - val_accuracy: 0.8320 - 61ms/epoch - 8ms/step
# Epoch 309/500
# 8/8 - 0s - loss: 1.2160e-04 - accuracy: 1.0000 - val_loss: 1.3959 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 310/500
# 8/8 - 0s - loss: 1.2061e-04 - accuracy: 1.0000 - val_loss: 1.3961 - val_accuracy: 0.8240 - 36ms/epoch - 4ms/step
# Epoch 311/500
# 8/8 - 0s - loss: 1.1941e-04 - accuracy: 1.0000 - val_loss: 1.3976 - val_accuracy: 0.8240 - 36ms/epoch - 5ms/step
# Epoch 312/500
# 8/8 - 0s - loss: 1.1839e-04 - accuracy: 1.0000 - val_loss: 1.3994 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 313/500
# 8/8 - 0s - loss: 1.1728e-04 - accuracy: 1.0000 - val_loss: 1.4009 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 314/500
# 8/8 - 0s - loss: 1.1627e-04 - accuracy: 1.0000 - val_loss: 1.4022 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 315/500
# 8/8 - 0s - loss: 1.1518e-04 - accuracy: 1.0000 - val_loss: 1.4047 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 316/500
# 8/8 - 0s - loss: 1.1420e-04 - accuracy: 1.0000 - val_loss: 1.4065 - val_accuracy: 0.8240 - 67ms/epoch - 8ms/step
# Epoch 317/500
# 8/8 - 0s - loss: 1.1316e-04 - accuracy: 1.0000 - val_loss: 1.4073 - val_accuracy: 0.8240 - 60ms/epoch - 8ms/step
# Epoch 318/500
# 8/8 - 0s - loss: 1.1218e-04 - accuracy: 1.0000 - val_loss: 1.4077 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 319/500
# 8/8 - 0s - loss: 1.1123e-04 - accuracy: 1.0000 - val_loss: 1.4093 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 320/500
# 8/8 - 0s - loss: 1.1019e-04 - accuracy: 1.0000 - val_loss: 1.4114 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 321/500
# 8/8 - 0s - loss: 1.0937e-04 - accuracy: 1.0000 - val_loss: 1.4128 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 322/500
# 8/8 - 0s - loss: 1.0842e-04 - accuracy: 1.0000 - val_loss: 1.4137 - val_accuracy: 0.8240 - 41ms/epoch - 5ms/step
# Epoch 323/500
# 8/8 - 0s - loss: 1.0733e-04 - accuracy: 1.0000 - val_loss: 1.4155 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 324/500
# 8/8 - 0s - loss: 1.0638e-04 - accuracy: 1.0000 - val_loss: 1.4170 - val_accuracy: 0.8240 - 47ms/epoch - 6ms/step
# Epoch 325/500
# 8/8 - 0s - loss: 1.0548e-04 - accuracy: 1.0000 - val_loss: 1.4188 - val_accuracy: 0.8240 - 48ms/epoch - 6ms/step
# Epoch 326/500
# 8/8 - 0s - loss: 1.0457e-04 - accuracy: 1.0000 - val_loss: 1.4199 - val_accuracy: 0.8240 - 47ms/epoch - 6ms/step
# Epoch 327/500
# 8/8 - 0s - loss: 1.0379e-04 - accuracy: 1.0000 - val_loss: 1.4213 - val_accuracy: 0.8240 - 49ms/epoch - 6ms/step
# Epoch 328/500
# 8/8 - 0s - loss: 1.0278e-04 - accuracy: 1.0000 - val_loss: 1.4227 - val_accuracy: 0.8240 - 65ms/epoch - 8ms/step
# Epoch 329/500
# 8/8 - 0s - loss: 1.0188e-04 - accuracy: 1.0000 - val_loss: 1.4248 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 330/500
# 8/8 - 0s - loss: 1.0110e-04 - accuracy: 1.0000 - val_loss: 1.4260 - val_accuracy: 0.8240 - 64ms/epoch - 8ms/step
# Epoch 331/500
# 8/8 - 0s - loss: 1.0033e-04 - accuracy: 1.0000 - val_loss: 1.4271 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 332/500
# 8/8 - 0s - loss: 9.9357e-05 - accuracy: 1.0000 - val_loss: 1.4285 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 333/500
# 8/8 - 0s - loss: 9.8556e-05 - accuracy: 1.0000 - val_loss: 1.4303 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 334/500
# 8/8 - 0s - loss: 9.7612e-05 - accuracy: 1.0000 - val_loss: 1.4316 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 335/500
# 8/8 - 0s - loss: 9.6678e-05 - accuracy: 1.0000 - val_loss: 1.4332 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 336/500
# 8/8 - 0s - loss: 9.6149e-05 - accuracy: 1.0000 - val_loss: 1.4353 - val_accuracy: 0.8240 - 53ms/epoch - 7ms/step
# Epoch 337/500
# 8/8 - 0s - loss: 9.5115e-05 - accuracy: 1.0000 - val_loss: 1.4360 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 338/500
# 8/8 - 0s - loss: 9.4475e-05 - accuracy: 1.0000 - val_loss: 1.4367 - val_accuracy: 0.8240 - 44ms/epoch - 5ms/step
# Epoch 339/500
# 8/8 - 0s - loss: 9.3570e-05 - accuracy: 1.0000 - val_loss: 1.4390 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 340/500
# 8/8 - 0s - loss: 9.2768e-05 - accuracy: 1.0000 - val_loss: 1.4408 - val_accuracy: 0.8240 - 64ms/epoch - 8ms/step
# Epoch 341/500
# 8/8 - 0s - loss: 9.2026e-05 - accuracy: 1.0000 - val_loss: 1.4418 - val_accuracy: 0.8240 - 70ms/epoch - 9ms/step
# Epoch 342/500
# 8/8 - 0s - loss: 9.1168e-05 - accuracy: 1.0000 - val_loss: 1.4429 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 343/500
# 8/8 - 0s - loss: 9.0481e-05 - accuracy: 1.0000 - val_loss: 1.4445 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 344/500
# 8/8 - 0s - loss: 8.9845e-05 - accuracy: 1.0000 - val_loss: 1.4459 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 345/500
# 8/8 - 0s - loss: 8.9154e-05 - accuracy: 1.0000 - val_loss: 1.4476 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 346/500
# 8/8 - 0s - loss: 8.8239e-05 - accuracy: 1.0000 - val_loss: 1.4482 - val_accuracy: 0.8240 - 54ms/epoch - 7ms/step
# Epoch 347/500
# 8/8 - 0s - loss: 8.7489e-05 - accuracy: 1.0000 - val_loss: 1.4496 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 348/500
# 8/8 - 0s - loss: 8.6748e-05 - accuracy: 1.0000 - val_loss: 1.4513 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 349/500
# 8/8 - 0s - loss: 8.6095e-05 - accuracy: 1.0000 - val_loss: 1.4521 - val_accuracy: 0.8240 - 62ms/epoch - 8ms/step
# Epoch 350/500
# 8/8 - 0s - loss: 8.5423e-05 - accuracy: 1.0000 - val_loss: 1.4533 - val_accuracy: 0.8240 - 51ms/epoch - 6ms/step
# Epoch 351/500
# 8/8 - 0s - loss: 8.4591e-05 - accuracy: 1.0000 - val_loss: 1.4546 - val_accuracy: 0.8240 - 41ms/epoch - 5ms/step
# Epoch 352/500
# 8/8 - 0s - loss: 8.3782e-05 - accuracy: 1.0000 - val_loss: 1.4550 - val_accuracy: 0.8240 - 65ms/epoch - 8ms/step
# Epoch 353/500
# 8/8 - 0s - loss: 8.3195e-05 - accuracy: 1.0000 - val_loss: 1.4561 - val_accuracy: 0.8240 - 49ms/epoch - 6ms/step
# Epoch 354/500
# 8/8 - 0s - loss: 8.2493e-05 - accuracy: 1.0000 - val_loss: 1.4573 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 355/500
# 8/8 - 0s - loss: 8.1802e-05 - accuracy: 1.0000 - val_loss: 1.4589 - val_accuracy: 0.8240 - 60ms/epoch - 8ms/step
# Epoch 356/500
# 8/8 - 0s - loss: 8.1082e-05 - accuracy: 1.0000 - val_loss: 1.4606 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 357/500
# 8/8 - 0s - loss: 8.0331e-05 - accuracy: 1.0000 - val_loss: 1.4621 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 358/500
# 8/8 - 0s - loss: 7.9859e-05 - accuracy: 1.0000 - val_loss: 1.4633 - val_accuracy: 0.8240 - 44ms/epoch - 6ms/step
# Epoch 359/500
# 8/8 - 0s - loss: 7.9032e-05 - accuracy: 1.0000 - val_loss: 1.4650 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 360/500
# 8/8 - 0s - loss: 7.8236e-05 - accuracy: 1.0000 - val_loss: 1.4667 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 361/500
# 8/8 - 0s - loss: 7.7608e-05 - accuracy: 1.0000 - val_loss: 1.4679 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 362/500
# 8/8 - 0s - loss: 7.6933e-05 - accuracy: 1.0000 - val_loss: 1.4700 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 363/500
# 8/8 - 0s - loss: 7.6242e-05 - accuracy: 1.0000 - val_loss: 1.4721 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 364/500
# 8/8 - 0s - loss: 7.5588e-05 - accuracy: 1.0000 - val_loss: 1.4740 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 365/500
# 8/8 - 0s - loss: 7.4992e-05 - accuracy: 1.0000 - val_loss: 1.4750 - val_accuracy: 0.8240 - 65ms/epoch - 8ms/step
# Epoch 366/500
# 8/8 - 0s - loss: 7.4269e-05 - accuracy: 1.0000 - val_loss: 1.4765 - val_accuracy: 0.8240 - 49ms/epoch - 6ms/step
# Epoch 367/500
# 8/8 - 0s - loss: 7.3590e-05 - accuracy: 1.0000 - val_loss: 1.4779 - val_accuracy: 0.8240 - 44ms/epoch - 5ms/step
# Epoch 368/500
# 8/8 - 0s - loss: 7.2879e-05 - accuracy: 1.0000 - val_loss: 1.4799 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 369/500
# 8/8 - 0s - loss: 7.2197e-05 - accuracy: 1.0000 - val_loss: 1.4821 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 370/500
# 8/8 - 0s - loss: 7.1780e-05 - accuracy: 1.0000 - val_loss: 1.4832 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 371/500
# 8/8 - 0s - loss: 7.0941e-05 - accuracy: 1.0000 - val_loss: 1.4856 - val_accuracy: 0.8240 - 46ms/epoch - 6ms/step
# Epoch 372/500
# 8/8 - 0s - loss: 7.0327e-05 - accuracy: 1.0000 - val_loss: 1.4865 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 373/500
# 8/8 - 0s - loss: 6.9744e-05 - accuracy: 1.0000 - val_loss: 1.4872 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 374/500
# 8/8 - 0s - loss: 6.9139e-05 - accuracy: 1.0000 - val_loss: 1.4891 - val_accuracy: 0.8320 - 63ms/epoch - 8ms/step
# Epoch 375/500
# 8/8 - 0s - loss: 6.8528e-05 - accuracy: 1.0000 - val_loss: 1.4907 - val_accuracy: 0.8320 - 63ms/epoch - 8ms/step
# Epoch 376/500
# 8/8 - 0s - loss: 6.7941e-05 - accuracy: 1.0000 - val_loss: 1.4921 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 377/500
# 8/8 - 0s - loss: 6.7420e-05 - accuracy: 1.0000 - val_loss: 1.4949 - val_accuracy: 0.8320 - 49ms/epoch - 6ms/step
# Epoch 378/500
# 8/8 - 0s - loss: 6.6916e-05 - accuracy: 1.0000 - val_loss: 1.4950 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 379/500
# 8/8 - 0s - loss: 6.6315e-05 - accuracy: 1.0000 - val_loss: 1.4963 - val_accuracy: 0.8240 - 51ms/epoch - 6ms/step
# Epoch 380/500
# 8/8 - 0s - loss: 6.5756e-05 - accuracy: 1.0000 - val_loss: 1.4984 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 381/500
# 8/8 - 0s - loss: 6.5083e-05 - accuracy: 1.0000 - val_loss: 1.4999 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 382/500
# 8/8 - 0s - loss: 6.4536e-05 - accuracy: 1.0000 - val_loss: 1.5004 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 383/500
# 8/8 - 0s - loss: 6.4009e-05 - accuracy: 1.0000 - val_loss: 1.5026 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 384/500
# 8/8 - 0s - loss: 6.3382e-05 - accuracy: 1.0000 - val_loss: 1.5040 - val_accuracy: 0.8240 - 47ms/epoch - 6ms/step
# Epoch 385/500
# 8/8 - 0s - loss: 6.2835e-05 - accuracy: 1.0000 - val_loss: 1.5050 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 386/500
# 8/8 - 0s - loss: 6.2649e-05 - accuracy: 1.0000 - val_loss: 1.5051 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 387/500
# 8/8 - 0s - loss: 6.1854e-05 - accuracy: 1.0000 - val_loss: 1.5069 - val_accuracy: 0.8240 - 55ms/epoch - 7ms/step
# Epoch 388/500
# 8/8 - 0s - loss: 6.1343e-05 - accuracy: 1.0000 - val_loss: 1.5100 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 389/500
# 8/8 - 0s - loss: 6.1009e-05 - accuracy: 1.0000 - val_loss: 1.5120 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 390/500
# 8/8 - 0s - loss: 6.0453e-05 - accuracy: 1.0000 - val_loss: 1.5140 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 391/500
# 8/8 - 0s - loss: 5.9895e-05 - accuracy: 1.0000 - val_loss: 1.5139 - val_accuracy: 0.8240 - 62ms/epoch - 8ms/step
# Epoch 392/500
# 8/8 - 0s - loss: 5.9412e-05 - accuracy: 1.0000 - val_loss: 1.5150 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 393/500
# 8/8 - 0s - loss: 5.8833e-05 - accuracy: 1.0000 - val_loss: 1.5173 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 394/500
# 8/8 - 0s - loss: 5.8290e-05 - accuracy: 1.0000 - val_loss: 1.5193 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 395/500
# 8/8 - 0s - loss: 5.7884e-05 - accuracy: 1.0000 - val_loss: 1.5201 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 396/500
# 8/8 - 0s - loss: 5.7256e-05 - accuracy: 1.0000 - val_loss: 1.5216 - val_accuracy: 0.8240 - 55ms/epoch - 7ms/step
# Epoch 397/500
# 8/8 - 0s - loss: 5.6687e-05 - accuracy: 1.0000 - val_loss: 1.5235 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 398/500
# 8/8 - 0s - loss: 5.6107e-05 - accuracy: 1.0000 - val_loss: 1.5260 - val_accuracy: 0.8240 - 49ms/epoch - 6ms/step
# Epoch 399/500
# 8/8 - 0s - loss: 5.5631e-05 - accuracy: 1.0000 - val_loss: 1.5272 - val_accuracy: 0.8240 - 39ms/epoch - 5ms/step
# Epoch 400/500
# 8/8 - 0s - loss: 5.5050e-05 - accuracy: 1.0000 - val_loss: 1.5285 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 401/500
# 8/8 - 0s - loss: 5.4695e-05 - accuracy: 1.0000 - val_loss: 1.5299 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 402/500
# 8/8 - 0s - loss: 5.4065e-05 - accuracy: 1.0000 - val_loss: 1.5312 - val_accuracy: 0.8240 - 41ms/epoch - 5ms/step
# Epoch 403/500
# 8/8 - 0s - loss: 5.3640e-05 - accuracy: 1.0000 - val_loss: 1.5327 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 404/500
# 8/8 - 0s - loss: 5.3162e-05 - accuracy: 1.0000 - val_loss: 1.5346 - val_accuracy: 0.8240 - 47ms/epoch - 6ms/step
# Epoch 405/500
# 8/8 - 0s - loss: 5.2721e-05 - accuracy: 1.0000 - val_loss: 1.5362 - val_accuracy: 0.8240 - 47ms/epoch - 6ms/step
# Epoch 406/500
# 8/8 - 0s - loss: 5.2257e-05 - accuracy: 1.0000 - val_loss: 1.5383 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 407/500
# 8/8 - 0s - loss: 5.1852e-05 - accuracy: 1.0000 - val_loss: 1.5392 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 408/500
# 8/8 - 0s - loss: 5.1395e-05 - accuracy: 1.0000 - val_loss: 1.5409 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 409/500
# 8/8 - 0s - loss: 5.1043e-05 - accuracy: 1.0000 - val_loss: 1.5424 - val_accuracy: 0.8240 - 51ms/epoch - 6ms/step
# Epoch 410/500
# 8/8 - 0s - loss: 5.0581e-05 - accuracy: 1.0000 - val_loss: 1.5435 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 411/500
# 8/8 - 0s - loss: 5.0226e-05 - accuracy: 1.0000 - val_loss: 1.5445 - val_accuracy: 0.8240 - 44ms/epoch - 5ms/step
# Epoch 412/500
# 8/8 - 0s - loss: 4.9687e-05 - accuracy: 1.0000 - val_loss: 1.5461 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 413/500
# 8/8 - 0s - loss: 4.9240e-05 - accuracy: 1.0000 - val_loss: 1.5476 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 414/500
# 8/8 - 0s - loss: 4.8851e-05 - accuracy: 1.0000 - val_loss: 1.5495 - val_accuracy: 0.8240 - 46ms/epoch - 6ms/step
# Epoch 415/500
# 8/8 - 0s - loss: 4.8456e-05 - accuracy: 1.0000 - val_loss: 1.5507 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 416/500
# 8/8 - 0s - loss: 4.8040e-05 - accuracy: 1.0000 - val_loss: 1.5523 - val_accuracy: 0.8240 - 55ms/epoch - 7ms/step
# Epoch 417/500
# 8/8 - 0s - loss: 4.7621e-05 - accuracy: 1.0000 - val_loss: 1.5541 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 418/500
# 8/8 - 0s - loss: 4.7284e-05 - accuracy: 1.0000 - val_loss: 1.5552 - val_accuracy: 0.8240 - 55ms/epoch - 7ms/step
# Epoch 419/500
# 8/8 - 0s - loss: 4.6889e-05 - accuracy: 1.0000 - val_loss: 1.5567 - val_accuracy: 0.8240 - 59ms/epoch - 7ms/step
# Epoch 420/500
# 8/8 - 0s - loss: 4.6520e-05 - accuracy: 1.0000 - val_loss: 1.5579 - val_accuracy: 0.8240 - 65ms/epoch - 8ms/step
# Epoch 421/500
# 8/8 - 0s - loss: 4.6190e-05 - accuracy: 1.0000 - val_loss: 1.5590 - val_accuracy: 0.8240 - 58ms/epoch - 7ms/step
# Epoch 422/500
# 8/8 - 0s - loss: 4.5803e-05 - accuracy: 1.0000 - val_loss: 1.5602 - val_accuracy: 0.8240 - 39ms/epoch - 5ms/step
# Epoch 423/500
# 8/8 - 0s - loss: 4.5472e-05 - accuracy: 1.0000 - val_loss: 1.5621 - val_accuracy: 0.8240 - 54ms/epoch - 7ms/step
# Epoch 424/500
# 8/8 - 0s - loss: 4.5135e-05 - accuracy: 1.0000 - val_loss: 1.5631 - val_accuracy: 0.8240 - 39ms/epoch - 5ms/step
# Epoch 425/500
# 8/8 - 0s - loss: 4.4692e-05 - accuracy: 1.0000 - val_loss: 1.5650 - val_accuracy: 0.8240 - 42ms/epoch - 5ms/step
# Epoch 426/500
# 8/8 - 0s - loss: 4.4460e-05 - accuracy: 1.0000 - val_loss: 1.5659 - val_accuracy: 0.8240 - 50ms/epoch - 6ms/step
# Epoch 427/500
# 8/8 - 0s - loss: 4.3982e-05 - accuracy: 1.0000 - val_loss: 1.5676 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 428/500
# 8/8 - 0s - loss: 4.3624e-05 - accuracy: 1.0000 - val_loss: 1.5685 - val_accuracy: 0.8240 - 44ms/epoch - 6ms/step
# Epoch 429/500
# 8/8 - 0s - loss: 4.3400e-05 - accuracy: 1.0000 - val_loss: 1.5691 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 430/500
# 8/8 - 0s - loss: 4.2955e-05 - accuracy: 1.0000 - val_loss: 1.5700 - val_accuracy: 0.8240 - 53ms/epoch - 7ms/step
# Epoch 431/500
# 8/8 - 0s - loss: 4.2707e-05 - accuracy: 1.0000 - val_loss: 1.5721 - val_accuracy: 0.8240 - 54ms/epoch - 7ms/step
# Epoch 432/500
# 8/8 - 0s - loss: 4.2420e-05 - accuracy: 1.0000 - val_loss: 1.5720 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 433/500
# 8/8 - 0s - loss: 4.2198e-05 - accuracy: 1.0000 - val_loss: 1.5733 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 434/500
# 8/8 - 0s - loss: 4.1837e-05 - accuracy: 1.0000 - val_loss: 1.5745 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 435/500
# 8/8 - 0s - loss: 4.1463e-05 - accuracy: 1.0000 - val_loss: 1.5763 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 436/500
# 8/8 - 0s - loss: 4.1116e-05 - accuracy: 1.0000 - val_loss: 1.5782 - val_accuracy: 0.8240 - 40ms/epoch - 5ms/step
# Epoch 437/500
# 8/8 - 0s - loss: 4.0735e-05 - accuracy: 1.0000 - val_loss: 1.5796 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 438/500
# 8/8 - 0s - loss: 4.0420e-05 - accuracy: 1.0000 - val_loss: 1.5806 - val_accuracy: 0.8240 - 61ms/epoch - 8ms/step
# Epoch 439/500
# 8/8 - 0s - loss: 4.0118e-05 - accuracy: 1.0000 - val_loss: 1.5819 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 440/500
# 8/8 - 0s - loss: 3.9862e-05 - accuracy: 1.0000 - val_loss: 1.5822 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 441/500
# 8/8 - 0s - loss: 3.9663e-05 - accuracy: 1.0000 - val_loss: 1.5837 - val_accuracy: 0.8240 - 52ms/epoch - 7ms/step
# Epoch 442/500
# 8/8 - 0s - loss: 3.9347e-05 - accuracy: 1.0000 - val_loss: 1.5845 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 443/500
# 8/8 - 0s - loss: 3.9063e-05 - accuracy: 1.0000 - val_loss: 1.5862 - val_accuracy: 0.8240 - 49ms/epoch - 6ms/step
# Epoch 444/500
# 8/8 - 0s - loss: 3.8687e-05 - accuracy: 1.0000 - val_loss: 1.5881 - val_accuracy: 0.8240 - 36ms/epoch - 4ms/step
# Epoch 445/500
# 8/8 - 0s - loss: 3.8370e-05 - accuracy: 1.0000 - val_loss: 1.5895 - val_accuracy: 0.8240 - 57ms/epoch - 7ms/step
# Epoch 446/500
# 8/8 - 0s - loss: 3.8055e-05 - accuracy: 1.0000 - val_loss: 1.5907 - val_accuracy: 0.8240 - 63ms/epoch - 8ms/step
# Epoch 447/500
# 8/8 - 0s - loss: 3.7754e-05 - accuracy: 1.0000 - val_loss: 1.5913 - val_accuracy: 0.8240 - 38ms/epoch - 5ms/step
# Epoch 448/500
# 8/8 - 0s - loss: 3.7486e-05 - accuracy: 1.0000 - val_loss: 1.5929 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 449/500
# 8/8 - 0s - loss: 3.7249e-05 - accuracy: 1.0000 - val_loss: 1.5942 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 450/500
# 8/8 - 0s - loss: 3.6896e-05 - accuracy: 1.0000 - val_loss: 1.5946 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 451/500
# 8/8 - 0s - loss: 3.6701e-05 - accuracy: 1.0000 - val_loss: 1.5954 - val_accuracy: 0.8240 - 37ms/epoch - 5ms/step
# Epoch 452/500
# 8/8 - 0s - loss: 3.6383e-05 - accuracy: 1.0000 - val_loss: 1.5967 - val_accuracy: 0.8240 - 36ms/epoch - 5ms/step
# Epoch 453/500
# 8/8 - 0s - loss: 3.6098e-05 - accuracy: 1.0000 - val_loss: 1.5980 - val_accuracy: 0.8240 - 39ms/epoch - 5ms/step
# Epoch 454/500
# 8/8 - 0s - loss: 3.5802e-05 - accuracy: 1.0000 - val_loss: 1.5988 - val_accuracy: 0.8240 - 56ms/epoch - 7ms/step
# Epoch 455/500
# 8/8 - 0s - loss: 3.5553e-05 - accuracy: 1.0000 - val_loss: 1.5993 - val_accuracy: 0.8240 - 66ms/epoch - 8ms/step
# Epoch 456/500
# 8/8 - 0s - loss: 3.5271e-05 - accuracy: 1.0000 - val_loss: 1.6002 - val_accuracy: 0.8240 - 51ms/epoch - 6ms/step
# Epoch 457/500
# 8/8 - 0s - loss: 3.4973e-05 - accuracy: 1.0000 - val_loss: 1.6021 - val_accuracy: 0.8240 - 44ms/epoch - 6ms/step
# Epoch 458/500
# 8/8 - 0s - loss: 3.4730e-05 - accuracy: 1.0000 - val_loss: 1.6037 - val_accuracy: 0.8240 - 43ms/epoch - 5ms/step
# Epoch 459/500
# 8/8 - 0s - loss: 3.4476e-05 - accuracy: 1.0000 - val_loss: 1.6053 - val_accuracy: 0.8240 - 45ms/epoch - 6ms/step
# Epoch 460/500
# 8/8 - 0s - loss: 3.4218e-05 - accuracy: 1.0000 - val_loss: 1.6060 - val_accuracy: 0.8240 - 62ms/epoch - 8ms/step
# Epoch 461/500
# 8/8 - 0s - loss: 3.3993e-05 - accuracy: 1.0000 - val_loss: 1.6070 - val_accuracy: 0.8240 - 77ms/epoch - 10ms/step
# Epoch 462/500
# 8/8 - 0s - loss: 3.3661e-05 - accuracy: 1.0000 - val_loss: 1.6085 - val_accuracy: 0.8240 - 79ms/epoch - 10ms/step
# Epoch 463/500
# 8/8 - 0s - loss: 3.3403e-05 - accuracy: 1.0000 - val_loss: 1.6098 - val_accuracy: 0.8240 - 112ms/epoch - 14ms/step
# Epoch 464/500
# 8/8 - 0s - loss: 3.3196e-05 - accuracy: 1.0000 - val_loss: 1.6105 - val_accuracy: 0.8240 - 117ms/epoch - 15ms/step
# Epoch 465/500
# 8/8 - 0s - loss: 3.2946e-05 - accuracy: 1.0000 - val_loss: 1.6121 - val_accuracy: 0.8240 - 113ms/epoch - 14ms/step
# Epoch 466/500
# 8/8 - 0s - loss: 3.2706e-05 - accuracy: 1.0000 - val_loss: 1.6138 - val_accuracy: 0.8240 - 81ms/epoch - 10ms/step
# Epoch 467/500
# 8/8 - 0s - loss: 3.2439e-05 - accuracy: 1.0000 - val_loss: 1.6146 - val_accuracy: 0.8240 - 71ms/epoch - 9ms/step
# Epoch 468/500
# 8/8 - 0s - loss: 3.2182e-05 - accuracy: 1.0000 - val_loss: 1.6156 - val_accuracy: 0.8240 - 81ms/epoch - 10ms/step
# Epoch 469/500
# 8/8 - 0s - loss: 3.1974e-05 - accuracy: 1.0000 - val_loss: 1.6167 - val_accuracy: 0.8240 - 99ms/epoch - 12ms/step
# Epoch 470/500
# 8/8 - 0s - loss: 3.1779e-05 - accuracy: 1.0000 - val_loss: 1.6180 - val_accuracy: 0.8240 - 75ms/epoch - 9ms/step
# Epoch 471/500
# 8/8 - 0s - loss: 3.1513e-05 - accuracy: 1.0000 - val_loss: 1.6195 - val_accuracy: 0.8240 - 159ms/epoch - 20ms/step
# Epoch 472/500
# 8/8 - 0s - loss: 3.1305e-05 - accuracy: 1.0000 - val_loss: 1.6211 - val_accuracy: 0.8240 - 120ms/epoch - 15ms/step
# Epoch 473/500
# 8/8 - 0s - loss: 3.1141e-05 - accuracy: 1.0000 - val_loss: 1.6220 - val_accuracy: 0.8240 - 126ms/epoch - 16ms/step
# Epoch 474/500
# 8/8 - 0s - loss: 3.0858e-05 - accuracy: 1.0000 - val_loss: 1.6233 - val_accuracy: 0.8240 - 102ms/epoch - 13ms/step
# Epoch 475/500
# 8/8 - 0s - loss: 3.0632e-05 - accuracy: 1.0000 - val_loss: 1.6250 - val_accuracy: 0.8240 - 78ms/epoch - 10ms/step
# Epoch 476/500
# 8/8 - 0s - loss: 3.0470e-05 - accuracy: 1.0000 - val_loss: 1.6264 - val_accuracy: 0.8240 - 108ms/epoch - 14ms/step
# Epoch 477/500
# 8/8 - 0s - loss: 3.0232e-05 - accuracy: 1.0000 - val_loss: 1.6274 - val_accuracy: 0.8240 - 119ms/epoch - 15ms/step
# Epoch 478/500
# 8/8 - 0s - loss: 3.0055e-05 - accuracy: 1.0000 - val_loss: 1.6285 - val_accuracy: 0.8240 - 119ms/epoch - 15ms/step
# Epoch 479/500
# 8/8 - 0s - loss: 2.9813e-05 - accuracy: 1.0000 - val_loss: 1.6302 - val_accuracy: 0.8240 - 89ms/epoch - 11ms/step
# Epoch 480/500
# 8/8 - 0s - loss: 2.9642e-05 - accuracy: 1.0000 - val_loss: 1.6320 - val_accuracy: 0.8240 - 96ms/epoch - 12ms/step
# Epoch 481/500
# 8/8 - 0s - loss: 2.9421e-05 - accuracy: 1.0000 - val_loss: 1.6325 - val_accuracy: 0.8240 - 100ms/epoch - 12ms/step
# Epoch 482/500
# 8/8 - 0s - loss: 2.9183e-05 - accuracy: 1.0000 - val_loss: 1.6331 - val_accuracy: 0.8240 - 157ms/epoch - 20ms/step
# Epoch 483/500
# 8/8 - 0s - loss: 2.8983e-05 - accuracy: 1.0000 - val_loss: 1.6345 - val_accuracy: 0.8240 - 120ms/epoch - 15ms/step
# Epoch 484/500
# 8/8 - 0s - loss: 2.8778e-05 - accuracy: 1.0000 - val_loss: 1.6359 - val_accuracy: 0.8240 - 93ms/epoch - 12ms/step
# Epoch 485/500
# 8/8 - 0s - loss: 2.8570e-05 - accuracy: 1.0000 - val_loss: 1.6370 - val_accuracy: 0.8240 - 93ms/epoch - 12ms/step
# Epoch 486/500
# 8/8 - 0s - loss: 2.8360e-05 - accuracy: 1.0000 - val_loss: 1.6383 - val_accuracy: 0.8240 - 72ms/epoch - 9ms/step
# Epoch 487/500
# 8/8 - 0s - loss: 2.8155e-05 - accuracy: 1.0000 - val_loss: 1.6391 - val_accuracy: 0.8240 - 83ms/epoch - 10ms/step
# Epoch 488/500
# 8/8 - 0s - loss: 2.7952e-05 - accuracy: 1.0000 - val_loss: 1.6396 - val_accuracy: 0.8240 - 104ms/epoch - 13ms/step
# Epoch 489/500
# 8/8 - 0s - loss: 2.7756e-05 - accuracy: 1.0000 - val_loss: 1.6408 - val_accuracy: 0.8240 - 99ms/epoch - 12ms/step
# Epoch 490/500
# 8/8 - 0s - loss: 2.7543e-05 - accuracy: 1.0000 - val_loss: 1.6420 - val_accuracy: 0.8240 - 121ms/epoch - 15ms/step
# Epoch 491/500
# 8/8 - 0s - loss: 2.7339e-05 - accuracy: 1.0000 - val_loss: 1.6428 - val_accuracy: 0.8240 - 185ms/epoch - 23ms/step
# Epoch 492/500
# 8/8 - 0s - loss: 2.7188e-05 - accuracy: 1.0000 - val_loss: 1.6438 - val_accuracy: 0.8240 - 113ms/epoch - 14ms/step
# Epoch 493/500
# 8/8 - 0s - loss: 2.6946e-05 - accuracy: 1.0000 - val_loss: 1.6461 - val_accuracy: 0.8240 - 115ms/epoch - 14ms/step
# Epoch 494/500
# 8/8 - 0s - loss: 2.6758e-05 - accuracy: 1.0000 - val_loss: 1.6479 - val_accuracy: 0.8240 - 84ms/epoch - 10ms/step
# Epoch 495/500
# 8/8 - 0s - loss: 2.6546e-05 - accuracy: 1.0000 - val_loss: 1.6493 - val_accuracy: 0.8240 - 60ms/epoch - 7ms/step
# Epoch 496/500
# 8/8 - 0s - loss: 2.6388e-05 - accuracy: 1.0000 - val_loss: 1.6496 - val_accuracy: 0.8240 - 76ms/epoch - 9ms/step
# Epoch 497/500
# 8/8 - 0s - loss: 2.6207e-05 - accuracy: 1.0000 - val_loss: 1.6510 - val_accuracy: 0.8240 - 83ms/epoch - 10ms/step
# Epoch 498/500
# 8/8 - 0s - loss: 2.6017e-05 - accuracy: 1.0000 - val_loss: 1.6522 - val_accuracy: 0.8240 - 81ms/epoch - 10ms/step
# Epoch 499/500
# 8/8 - 0s - loss: 2.5835e-05 - accuracy: 1.0000 - val_loss: 1.6531 - val_accuracy: 0.8240 - 109ms/epoch - 14ms/step
# Epoch 500/500
# 8/8 - 0s - loss: 2.5658e-05 - accuracy: 1.0000 - val_loss: 1.6543 - val_accuracy: 0.8240 - 84ms/epoch - 11ms/step

# %% [markdown]
# We see that the model accuracy hovers around 100% in the testing data which is better than ensemble model (accuracy may change slightly run-to-run). We can try larger network inclear number of epochs however, very likely this is the maximum prediction or performance of the model based on the dataset. We may also end of overfitting the training dataset. Again, note that the dataset is relatively small for neural network.

# %% [markdown]
# ## **4. Evaluate model**
#
# We evaluate the model on test dataset and obtain the score and accuracy.
# Score is the evaluation of the loss function for a given input.

# %%
score, acc = model.evaluate(test_X, test_Y)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6543 - accuracy: 0.8240
# Test score: 1.6542524099349976
# Test accuracy: 0.8240000009536743

# %% [markdown]
# So we get 82.40% accuracy on the test dataset with this fully connected neural network (varies little bit run to run).
# This is comparable and not significantly better than ensemble method done earlier.
# NN acccuracy expected to improve with larger amount of training data.

# %% [markdown]
# ### **Training and validation curves vs. epoch**

# %%
# Plot the loss and accuracy curves for training and validation vs. epochs

fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="Testing loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Testing accuracy")
legend = ax[1].legend(loc='best', shadow=True)

plt.show()

# %% [markdown]
# After about 30 epochs, testing loss starts to become higher than training loss and exactly opposite for accuracy: testing accuracy starts to get lower than training accuracy. Basically we are starting to overfit here.
# Therefore, we get an optimal accuracy of close to 80% using this model.

# %% [markdown]
# ### **Confusion matrix using this model**
#
# Let us have a look at the correct and misclasssification in the confusion matrix.
# I am using the below function for confusion matrix.

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(test_X)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(test_Y,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(2))
plt.grid(False)
plt.show()
